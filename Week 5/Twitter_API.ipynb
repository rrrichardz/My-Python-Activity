# %% [markdown]
# ### Twitter API

# %% [markdown]
# #### 1. Create YAML file

# %% [markdown]
# #### 2. Import YAML file into Jupyter Notebook

# %%
# install and import YAML library
# !pip install pyyaml

# import yaml
import yaml
from yaml.loader import SafeLoader

# import the yaml file - remember to specify the whole path
twitter_creds = yaml.safe_load(open('Twitter.yaml', 'r').read())
# Out:
# Requirement already satisfied: pyyaml in c:\users\richa\anaconda3\lib\site-packages (6.0)

# %%
# view the keys in the dictionary
twitter_creds.keys()
# Out:
# dict_keys(['api_key', 'api_secret_key', 'access_token', 'access_token_secret'])

# %% [markdown]
# #### 3. Install the Twitter API module

# %%
# install twitter api
# !pip install twitter

# import library
from twitter import *
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %%
# pass the twitter credentials
twitter_api = Twitter(auth = OAuth(twitter_creds['access_token'],
                                  twitter_creds['access_token_secret'],
                                  twitter_creds['api_key'],
                                  twitter_creds['api_secret_key']))

# %% [markdown]
# #### Connecting to Twitter

# %%
# see if you are connected
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000001939B646160>

# %%
# run a test with #python
some_python_tweets = twitter_api.search.tweets(q = '#python')

# view output
print(some_python_tweets)
# Out:
# {'statuses': [{'created_at': 'Sun Apr 24 22:01:37 +0000 2022', 'id': 1518349469909233665, 'id_str': '1518349469909233665', 'text': 'RT @ArafatA39014542: Contact me:\nhttps://t.co/r2RTfGMVoi\n#JobSeekersSA #Lebanon #Programming #DigitalMarketing #cybersecurity #MachineLearn…', 'truncated': False, 'entities': {'hashtags': [{'text': 'JobSeekersSA', 'indices': [57, 70]}, {'text': 'Lebanon', 'indices': [71, 79]}, {'text': 'Programming', 'indices': [80, 92]}, {'text': 'DigitalMarketing', 'indices': [93, 110]}, {'text': 'cybersecurity', 'indices': [111, 125]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ArafatA39014542', 'name': 'Arafat Tusher', 'id': 1349948820163989504, 'id_str': '1349948820163989504', 'indices': [3, 19]}], 'urls': [{'url': 'https://t.co/r2RTfGMVoi', 'expanded_url': 'https://fiverr.com/share/Px6Nb0', 'display_url': 'fiverr.com/share/Px6Nb0', 'indices': [33, 56]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.website.com" rel="nofollow">javascript-twitter-bot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 826097054342594560, 'id_str': '826097054342594560', 'name': 'JavaScript Tweets', 'screen_name': 'JSTweetsBot', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1440, 'friends_count': 578, 'listed_count': 54, 'created_at': 'Mon Jan 30 15:57:40 +0000 2017', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 41386, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/826458534049173504/0LKKW4Vs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826458534049173504/0LKKW4Vs_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Apr 24 22:00:08 +0000 2022', 'id': 1518349094359486464, 'id_str': '1518349094359486464', 'text': 'Contact me:\nhttps://t.co/r2RTfGMVoi\n#JobSeekersSA #Lebanon #Programming #DigitalMarketing #cybersecurity… https://t.co/R9xrwNBmkt', 'truncated': True, 'entities': {'hashtags': [{'text': 'JobSeekersSA', 'indices': [36, 49]}, {'text': 'Lebanon', 'indices': [50, 58]}, {'text': 'Programming', 'indices': [59, 71]}, {'text': 'DigitalMarketing', 'indices': [72, 89]}, {'text': 'cybersecurity', 'indices': [90, 104]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/r2RTfGMVoi', 'expanded_url': 'https://fiverr.com/share/Px6Nb0', 'display_url': 'fiverr.com/share/Px6Nb0', 'indices': [12, 35]}, {'url': 'https://t.co/R9xrwNBmkt', 'expanded_url': 'https://twitter.com/i/web/status/1518349094359486464', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [106, 129]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1349948820163989504, 'id_str': '1349948820163989504', 'name': 'Arafat Tusher', 'screen_name': 'ArafatA39014542', 'locat ...

# %% [markdown]
# #### Worldwide trends

# %%
# determine worldwide trends
trends_worldwide = twitter_api.trends.available(q = '#python')

# how many trends available
print(len(trends_worldwide))

# example of trends_worldwide
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %%
# write a twitter request
list_of_names = [_['name'] for _ in trends_worldwide]

# list of first 10
list_of_names[0:10]
# Out:
# ['Worldwide',
#  'Winnipeg',
#  'Ottawa',
#  'Quebec',
#  'Montreal',
#  'Toronto',
#  'Edmonton',
#  'Calgary',
#  'Vancouver',
#  'Birmingham']

# %%
# find London
our_city = 'London'

# create variable
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# view output
print(len(list_of_names_our_city))

# use index to find London
list_of_names_our_city[0]
# Out:
# 1
# {'name': 'London',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/44418',
#  'parentid': 23424975,
#  'country': 'United Kingdom',
#  'woeid': 44418,
#  'countryCode': 'GB'}

# %%
# list of where on earth identifies (woeid)
list_of_names_our_city[0]['woeid']
# Out:
# 44418

# %% [markdown]
# #### Trends per city

# %%
# look at trends in London
our_city_trends = twitter_api.trends.place(_id = list_of_names_our_city[0]['woeid'])

# view output
our_city_trends
# Out:
# [{'trends': [{'name': '#HarshRealityNosis',
#     'url': 'http://twitter.com/search?q=%23HarshRealityNosis',
#     'promoted_content': None,
#     'query': '%23HarshRealityNosis',
#     'tweet_volume': None},
#    {'name': '#CelebsForSmallBiz',
#     'url': 'http://twitter.com/search?q=%23CelebsForSmallBiz',
#     'promoted_content': None,
#     'query': '%23CelebsForSmallBiz',
#     'tweet_volume': None},
#    {'name': 'Championship',
#     'url': 'http://twitter.com/search?q=Championship',
#     'promoted_content': None,
#     'query': 'Championship',
#     'tweet_volume': 70736},
#    {'name': 'Wilbur',
#     'url': 'http://twitter.com/search?q=Wilbur',
#     'promoted_content': None,
#     'query': 'Wilbur',
#     'tweet_volume': 10593},
#    {'name': 'Conte',
#     'url': 'http://twitter.com/search?q=Conte',
#     'promoted_content': None,
#     'query': 'Conte',
#     'tweet_volume': 30020},
#    {'name': '#goingdown',
#     'url': 'http://twitter.com/search?q=%23goingdown',
#     'promoted_content': None,
#     'query': '%23goingdown',
#     'tweet_volume': None},
#    {'name': 'Leeds',
#     'url': 'http://twitter.com/search?q=Leeds',
#     'promoted_content': None,
#     'query': 'Leeds',
#     'tweet_volume': 14846},
#    {'name': 'attwell',
#     'url': 'http://twitter.com/search?q=attwell',
#     'promoted_content': None,
#     'query': 'attwell',
#     'tweet_volume': None},
#    {'name': 'Paul Mitchell',
#     'url': 'http://twitter.com/search?q=%22Paul+Mitchell%22',
#     'promoted_content': None,
#     'query': '%22Paul+Mitchell%22',
#     'tweet_volume': None},
#    {'name': 'Reds',
#     'url': 'http://twitter.com/search?q=Reds',
#     'promoted_content': None,
#     'query': 'Reds',
#     'tweet_volume': 41386},
#    {'name': 'Souness',
#     'url': 'http://twitter.com/search?q=Souness',
#     'promoted_content': None,
#     'query': 'Souness',
#     'tweet_volume': None},
#    {'name': 'Allan',
#     'url': 'http://twitter.com/search?q=Allan',
#     'promoted_content': None,
#     'query': 'Allan',
#     'tweet_volume': 19283},
#    {'name': 'Andy Robertson',
#     'url': 'http://twitter.com/search?q=%22Andy+Robertson%22',
#     'promoted_content': None,
#     'query': '%22Andy+Robertson%22',
#     'tweet_volume': None},
#    {'name': 'Goodison',
#     'url': 'http://twitter.com/search?q=Goodison',
#     'promoted_content': None,
#     'query': 'Goodison',
#     'tweet_volume': None},
#    {'name': 'Levy',
#     'url': 'http://twitter.com/search?q=Levy',
#     'promoted_content': None,
#     'query': 'Levy',
#     'tweet_volume': None},
#    {'name': 'Panthers',
#     'url': 'http://twitter.com/search?q=Panthers',
#     'promoted_content': None,
#     'query': 'Panthers',
#     'tweet_volume': 14581},
#    {'name': 'Basic Instinct',
#     'url': 'http://twitter.com/search?q=%22Basic+Instinct%22',
#     'promoted_content': None,
#     'query': '%22Basic+Instinct%22',
#     'tweet_volume': 12776},
#    {'name': 'Benitez',
#     'url': 'http://twitter.com/search?q=Benitez',
#     'promoted_content': None,
#     'query': 'Benitez',
#     'tweet_volume': None},
#    {'name': '#MarchAgainstImportedGovt',
#     'url': 'http://twitter.com/search?q=%23MarchAgainstImportedGovt',
#     'promoted_content': None,
#     'query': '%23MarchAgainstImportedGovt',
#     'tweet_volume': 2372022},
#    {'name': 'Macron',
#     'url': 'http://twitter.com/search?q=Macron',
#     'promoted_content': None,
#     'query': 'Macron',
#     'tweet_volume': 1221849},
#    {'name': 'Le Pen',
#     'url': 'http://twitter.com/search?q=%22Le+Pen%22',
#     'promoted_content': None,
#     'query': '%22Le+Pen%22',
#     'tweet_volume': 539466},
#    {'name': 'Everton',
#     'url': 'http://twitter.com/search?q=Everton',
#     'promoted_content': None,
#     'query': 'Everton',
#     'tweet_volume': 205980},
#    {'name': '#Grace',
#     'url': 'http://twitter.com/search?q=%23Grace',
#     'promoted_content': None,
#     'query': '%23Grace',
#     'tweet_volume': None},
#    {'name': 'Gordon',
#     'url': 'http://twitter.com/search?q=Gordon',
#     'promoted_content': None,
#     'query': 'Gordon',
#     'tweet_volume': 48551},
#    {'name': 'Ranboo',
#     'url': 'http://twitter.com/search?q=Ranboo',
#     'promoted_content': None,
#     'query': 'Ranboo',
#     'tweet_volume': 61978},
#    {'name': 'The French',
#     'url': 'http://twitter.com/search?q=%22The+French%22',
#     'promoted_content': None,
#     'query': '%22The+French%22',
#     'tweet_volume': 132386},
#    {'name': 'Origi',
#     'url': 'http://twitter.com/search?q=Origi',
#     'promoted_content': None,
#     'query': 'Origi',
#     'tweet_volume': 70738},
#    {'name': 'Richarlison',
#     'url': 'http://twitter.com/search?q=Richarlison',
#     'promoted_content': None,
#     'query': 'Richarlison',
#     'tweet_volume': 30527},
#    {'name': 'Milan',
#     'url': 'http://twitter.com/search?q=Milan',
#     'promoted_content': None,
#     'query': 'Milan',
#     'tweet_volume': 77712},
#    {'name': 'Pickford',
#     'url': 'http://twitter.com/search?q=Pickford',
#     'promoted_content': None,
#     'query': 'Pickford',
#     'tweet_volume': 24029},
#    {'name': 'Vive la France',
#     'url': 'http://twitter.com/search?q=%22Vive+la+France%22',
#     'promoted_content': None,
#     'query': '%22Vive+la+France%22',
#     'tweet_volume': 37046},
#    {'name': 'Matip',
#     'url': 'http://twitter.com/search?q=Matip',
#     'promoted_content': None,
#     'query': 'Matip',
#     'tweet_volume': None},
#    {'name': 'Diaz',
#     'url': 'http://twitter.com/search?q=Diaz',
#     'promoted_content': None,
#     'query': 'Diaz',
#     'tweet_volume': 116586},
#    {'name': 'Frexit',
#     'url': 'http://twitter.com/search?q=Frexit',
#     'promoted_content': None,
#     'query': 'Frexit',
#     'tweet_volume': None},
#    {'name': 'ONE OF US',
#     'url': 'http://twitter.com/search?q=%22ONE+OF+US%22',
#     'promoted_content': None,
#     'query': '%22ONE+OF+US%22',
#     'tweet_volume': 108483},
#    {'name': 'Slovenia',
#     'url': 'http://twitter.com/search?q=Slovenia',
#     'promoted_content': None,
#     'query': 'Slovenia',
#     'tweet_volume': 30860},
#    {'name': 'Carragher',
#     'url': 'http://twitter.com/search?q=Carragher',
#     'promoted_content': None,
#     'query': 'Carragher',
#     'tweet_volume': None},
#    {'name': 'Hyland',
#     'url': 'http://twitter.com/search?q=Hyland',
#     'promoted_content': None,
#     'query': 'Hyland',
#     'tweet_volume': None},
#    {'name': 'Tonali',
#     'url': 'http://twitter.com/search?q=Tonali',
#     'promoted_content': None,
#     'query': 'Tonali',
#     'tweet_volume': 15626},
#    {'name': 'Anfield',
#     'url': 'http://twitter.com/search?q=Anfield',
#     'promoted_content': None,
#     'query': 'Anfield',
#     'tweet_volume': 30600},
#    {'name': '42% of French',
#     'url': 'http://twitter.com/search?q=%2242%25+of+French%22',
#     'promoted_content': None,
#     'query': '%2242%25+of+French%22',
#     'tweet_volume': None},
#    {'name': 'Lampard',
#     'url': 'http://twitter.com/search?q=Lampard',
#     'promoted_content': None,
#     'query': 'Lampard',
#     'tweet_volume': 22492},
#    {'name': 'Team of the Season',
#     'url': 'http://twitter.com/search?q=%22Team+of+the+Season%22',
#     'promoted_content': None,
#     'query': '%22Team+of+the+Season%22',
#     'tweet_volume': 11077},
#    {'name': 'Rigged',
#     'url': 'http://twitter.com/search?q=Rigged',
#     'promoted_content': None,
#     'query': 'Rigged',
#     'tweet_volume': 22878},
#    {'name': 'Matt Lucas',
#     'url': 'http://twitter.com/search?q=%22Matt+Lucas%22',
#     'promoted_content': None,
#     'query': '%22Matt+Lucas%22',
#     'tweet_volume': None},
#    {'name': 'Poch',
#     'url': 'http://twitter.com/search?q=Poch',
#     'promoted_content': None,
#     'query': 'Poch',
#     'tweet_volume': None},
#    {'name': 'Melenchon',
#     'url': 'http://twitter.com/search?q=Melenchon',
#     'promoted_content': None,
#     'query': 'Melenchon',
#     'tweet_volume': 120105},
#    {'name': 'Leao',
#     'url': 'http://twitter.com/search?q=Leao',
#     'promoted_content': None,
#     'query': 'Leao',
#     'tweet_volume': 12910},
#    {'name': 'Mariana',
#     'url': 'http://twitter.com/search?q=Mariana',
#     'promoted_content': None,
#     'query': 'Mariana',
#     'tweet_volume': 47510}],
#   'as_of': '2022-04-24T22:10:25Z',
#   'created_at': '2022-04-20T05:45:31Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
# look at output as DataFrame
# import Pandas
import pandas as pd

# create DataFrame
our_city_trends_pd = pd.DataFrame(our_city_trends[0]['trends'])

# view DataFrame
our_city_trends_pd
# Out:
#                          name  \
# 0          #HarshRealityNosis
# 1          #CelebsForSmallBiz
# 2                Championship
# 3                      Wilbur
# 4                       Conte
# 5                  #goingdown
# 6                       Leeds
# 7                     attwell
# 8               Paul Mitchell
# 9                        Reds
# 10                    Souness
# 11                      Allan
# 12             Andy Robertson
# 13                   Goodison
# 14                       Levy
# 15                   Panthers
# 16             Basic Instinct
# 17                    Benitez
# 18  #MarchAgainstImportedGovt
# 19                     Macron
# 20                     Le Pen
# 21                    Everton
# 22                     #Grace
# 23                     Gordon
# 24                     Ranboo
# 25                 The French
# 26                      Origi
# 27                Richarlison
# 28                      Milan
# 29                   Pickford
# 30             Vive la France
# 31                      Matip
# 32                       Diaz
# 33                     Frexit
# 34                  ONE OF US
# 35                   Slovenia
# 36                  Carragher
# 37                     Hyland
# 38                     Tonali
# 39                    Anfield
# 40              42% of French
# 41                    Lampard
# 42         Team of the Season
# 43                     Rigged
# 44                 Matt Lucas
# 45                       Poch
# 46                  Melenchon
# 47                       Leao
# 48                    Mariana
#
#                                                   url promoted_content  \
# 0    http://twitter.com/search?q=%23HarshRealityNosis             None
# 1    http://twitter.com/search?q=%23CelebsForSmallBiz             None
# 2            http://twitter.com/search?q=Championship             None
# 3                  http://twitter.com/search?q=Wilbur             None
# 4                   http://twitter.com/search?q=Conte             None
# 5            http://twitter.com/search?q=%23goingdown             None
# 6                   http://twitter.com/search?q=Leeds             None
# 7                 http://twitter.com/search?q=attwell             None
# 8     http://twitter.com/search?q=%22Paul+Mitchell%22             None
# 9                    http://twitter.com/search?q=Reds             None
# 10                http://twitter.com/search?q=Souness             None
# 11                  http://twitter.com/search?q=Allan             None
# 12   http://twitter.com/search?q=%22Andy+Robertson%22             None
# 13               http://twitter.com/search?q=Goodison             None
# 14                   http://twitter.com/search?q=Levy             None
# 15               http://twitter.com/search?q=Panthers             None
# 16   http://twitter.com/search?q=%22Basic+Instinct%22             None
# 17                http://twitter.com/search?q=Benitez             None
# 18  http://twitter.com/search?q=%23MarchAgainstImp...             None
# 19                 http://twitter.com/search?q=Macron             None
# 20           http://twitter.com/search?q=%22Le+Pen%22             None
# 21                http://twitter.com/search?q=Everton             None
# 22               http://twitter.com/search?q=%23Grace             None
# 23                 http://twitter.com/search?q=Gordon             None
# 24                 http://twitter.com/search?q=Ranboo             None
# 25       http://twitter.com/search?q=%22The+French%22             None
# 26                  http://twitter.com/search?q=Origi             None
# 27            http://twitter.com/search?q=Richarlison             None
# 28                  http://twitter.com/search?q=Milan             None
# 29               http://twitter.com/search?q=Pickford             None
# 30   http://twitter.com/search?q=%22Vive+la+France%22             None
# 31                  http://twitter.com/search?q=Matip             None
# 32                   http://twitter.com/search?q=Diaz             None
# 33                 http://twitter.com/search?q=Frexit             None
# 34        http://twitter.com/search?q=%22ONE+OF+US%22             None
# 35               http://twitter.com/search?q=Slovenia             None
# 36              http://twitter.com/search?q=Carragher             None
# 37                 http://twitter.com/search?q=Hyland             None
# 38                 http://twitter.com/search?q=Tonali             None
# 39                http://twitter.com/search?q=Anfield             None
# 40  http://twitter.com/search?q=%2242%25+of+French%22             None
# 41                http://twitter.com/search?q=Lampard             None
# 42  http://twitter.com/search?q=%22Team+of+the+Sea...             None
# 43                 http://twitter.com/search?q=Rigged             None
# 44       http://twitter.com/search?q=%22Matt+Lucas%22             None
# 45                   http://twitter.com/search?q=Poch             None
# 46              http://twitter.com/search?q=Melenchon             None
# 47                   http://twitter.com/search?q=Leao             None
# 48                http://twitter.com/search?q=Mariana             None
#
#                           query  tweet_volume
# 0          %23HarshRealityNosis           NaN
# 1          %23CelebsForSmallBiz           NaN
# 2                  Championship       70736.0
# 3                        Wilbur       10593.0
# 4                         Conte       30020.0
# 5                  %23goingdown           NaN
# 6                         Leeds       14846.0
# 7                       attwell           NaN
# 8           %22Paul+Mitchell%22           NaN
# 9                          Reds       41386.0
# 10                      Souness           NaN
# 11                        Allan       19283.0
# 12         %22Andy+Robertson%22           NaN
# 13                     Goodison           NaN
# 14                         Levy           NaN
# 15                     Panthers       14581.0
# 16         %22Basic+Instinct%22       12776.0
# 17                      Benitez           NaN
# 18  %23MarchAgainstImportedGovt     2372022.0
# 19                       Macron     1221849.0
# 20                 %22Le+Pen%22      539466.0
# 21                      Everton      205980.0
# 22                     %23Grace           NaN
# 23                       Gordon       48551.0
# 24                       Ranboo       61978.0
# 25             %22The+French%22      132386.0
# 26                        Origi       70738.0
# 27                  Richarlison       30527.0
# 28                        Milan       77712.0
# 29                     Pickford       24029.0
# 30         %22Vive+la+France%22       37046.0
# 31                        Matip           NaN
# 32                         Diaz      116586.0
# 33                       Frexit           NaN
# 34              %22ONE+OF+US%22      108483.0
# 35                     Slovenia       30860.0
# 36                    Carragher           NaN
# 37                       Hyland           NaN
# 38                       Tonali       15626.0
# 39                      Anfield       30600.0
# 40        %2242%25+of+French%22           NaN
# 41                      Lampard       22492.0
# 42     %22Team+of+the+Season%22       11077.0
# 43                       Rigged       22878.0
# 44             %22Matt+Lucas%22           NaN
# 45                         Poch           NaN
# 46                    Melenchon      120105.0
# 47                         Leao       12910.0
# 48                      Mariana       47510.0

# %%
# narrow list down to 100,000 tweets
our_city_trends_over100k_pd = our_city_trends_pd[our_city_trends_pd['tweet_volume'] \
> 100000] \
.sort_values('tweet_volume', ascending = False)

# view the output
print(our_city_trends_over100k_pd.shape)
our_city_trends_over100k_pd
# Out:
# (8, 5)
#                          name  \
# 18  #MarchAgainstImportedGovt
# 19                     Macron
# 20                     Le Pen
# 21                    Everton
# 25                 The French
# 46                  Melenchon
# 32                       Diaz
# 34                  ONE OF US
#
#                                                   url promoted_content  \
# 18  http://twitter.com/search?q=%23MarchAgainstImp...             None
# 19                 http://twitter.com/search?q=Macron             None
# 20           http://twitter.com/search?q=%22Le+Pen%22             None
# 21                http://twitter.com/search?q=Everton             None
# 25       http://twitter.com/search?q=%22The+French%22             None
# 46              http://twitter.com/search?q=Melenchon             None
# 32                   http://twitter.com/search?q=Diaz             None
# 34        http://twitter.com/search?q=%22ONE+OF+US%22             None
#
#                           query  tweet_volume
# 18  %23MarchAgainstImportedGovt     2372022.0
# 19                       Macron     1221849.0
# 20                 %22Le+Pen%22      539466.0
# 21                      Everton      205980.0
# 25             %22The+French%22      132386.0
# 46                    Melenchon      120105.0
# 32                         Diaz      116586.0
# 34              %22ONE+OF+US%22      108483.0

# %%
# save output as CSV file
our_city_trends_over100k_pd.to_csv('our_city_trends_over100k.csv', index = False)

# %% [markdown]
# #### Common trends

# %%
# find Paris
our_city = 'Paris'

# create variable
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# view output
list_of_names_our_city[0]['woeid']
# Out:
# 615702

# %%
# search for each city
# import json
import json

# search for London
london_trends = twitter_api.trends.place(_id = 44418)

# view JSON output
print(json.dumps(london_trends, indent = 4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "#HarshRealityNosis",
#                 "url": "http://twitter.com/search?q=%23HarshRealityNosis",
#                 "promoted_content": null,
#                 "query": "%23HarshRealityNosis",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Brennan Johnson",
#                 "url": "http://twitter.com/search?q=%22Brennan+Johnson%22",
#                 "promoted_content": null,
#                 "query": "%22Brennan+Johnson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#CelebsForSmallBiz",
#                 "url": "http://twitter.com/search?q=%23CelebsForSmallBiz",
#                 "promoted_content": null,
#                 "query": "%23CelebsForSmallBiz",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Championship",
#                 "url": "http://twitter.com/search?q=Championship",
#                 "promoted_content": null,
#                 "query": "Championship",
#                 "tweet_volume": 71407
#             },
#             {
#                 "name": "Wilbur",
#                 "url": "http://twitter.com/search?q=Wilbur",
#                 "promoted_content": null,
#                 "query": "Wilbur",
#                 "tweet_volume": 10644
#             },
#             {
#                 "name": "Conte",
#                 "url": "http://twitter.com/search?q=Conte",
#                 "promoted_content": null,
#                 "query": "Conte",
#                 "tweet_volume": 30213
#             },
#             {
#                 "name": "Leeds",
#                 "url": "http://twitter.com/search?q=Leeds",
#                 "promoted_content": null,
#                 "query": "Leeds",
#                 "tweet_volume": 14918
#             },
#             {
#                 "name": "attwell",
#                 "url": "http://twitter.com/search?q=attwell",
#                 "promoted_content": null,
#                 "query": "attwell",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Merseyside",
#                 "url": "http://twitter.com/search?q=Merseyside",
#                 "promoted_content": null,
#                 "query": "Merseyside",
#                 "tweet_volume": 35193
#             },
#             {
#                 "name": "Reds",
#                 "url": "http://twitter.com/search?q=Reds",
#                 "promoted_content": null,
#                 "query": "Reds",
#                 "tweet_volume": 41578
#             },
#             {
#                 "name": "Paul Mitchell",
#                 "url": "http://twitter.com/search?q=%22Paul+Mitchell%22",
#                 "promoted_content": null,
#                 "query": "%22Paul+Mitchell%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Souness",
#                 "url": "http://twitter.com/search?q=Souness",
#                 "promoted_content": null,
#                 "query": "Souness",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Holgate",
#                 "url": "http://twitter.com/search?q=Holgate",
#                 "promoted_content": null,
#                 "query": "Holgate",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Allan",
#                 "url": "http://twitter.com/search?q=Allan",
#                 "promoted_content": null,
#                 "query": "Allan",
#                 "tweet_volume": 19394
#             },
#             {
#                 "name": "Andy Robertson",
#                 "url": "http://twitter.com/search?q=%22Andy+Robertson%22",
#                 "promoted_content": null,
#                 "query": "%22Andy+Robertson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Goodison",
#                 "url": "http://twitter.com/search?q=Goodison",
#                 "promoted_content": null,
#                 "query": "Goodison",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Levy",
#                 "url": "http://twitter.com/search?q=Levy",
#                 "promoted_content": null,
#                 "query": "Levy",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#JusticeForJohhnyDepp",
#                 "url": "http://twitter.com/search?q=%23JusticeForJohhnyDepp",
#                 "promoted_content": null,
#                 "query": "%23JusticeForJohhnyDepp",
#                 "tweet_volume": 12983
#             },
#             {
#                 "name": "Panthers",
#                 "url": "http://twitter.com/search?q=Panthers",
#                 "promoted_content": null,
#                 "query": "Panthers",
#                 "tweet_volume": 14650
#             },
#             {
#                 "name": "Macron",
#                 "url": "http://twitter.com/search?q=Macron",
#                 "promoted_content": null,
#                 "query": "Macron",
#                 "tweet_volume": 1246346
#             },
#             {
#                 "name": "Le Pen",
#                 "url": "http://twitter.com/search?q=%22Le+Pen%22",
#                 "promoted_content": null,
#                 "query": "%22Le+Pen%22",
#                 "tweet_volume": 544971
#             },
#             {
#                 "name": "Everton",
#                 "url": "http://twitter.com/search?q=Everton",
#                 "promoted_content": null,
#                 "query": "Everton",
#                 "tweet_volume": 206685
#             },
#             {
#                 "name": "#Grace",
#                 "url": "http://twitter.com/search?q=%23Grace",
#                 "promoted_content": null,
#                 "query": "%23Grace",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SASWhoDaresWins",
#                 "url": "http://twitter.com/search?q=%23SASWhoDaresWins",
#                 "promoted_content": null,
#                 "query": "%23SASWhoDaresWins",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ranboo",
#                 "url": "http://twitter.com/search?q=Ranboo",
#                 "promoted_content": null,
#                 "query": "Ranboo",
#                 "tweet_volume": 65956
#             },
#             {
#                 "name": "Gordon",
#                 "url": "http://twitter.com/search?q=Gordon",
#                 "promoted_content": null,
#                 "query": "Gordon",
#                 "tweet_volume": 49021
#             },
#             {
#                 "name": "The French",
#                 "url": "http://twitter.com/search?q=%22The+French%22",
#                 "promoted_content": null,
#                 "query": "%22The+French%22",
#                 "tweet_volume": 134486
#             },
#             {
#                 "name": "Origi",
#                 "url": "http://twitter.com/search?q=Origi",
#                 "promoted_content": null,
#                 "query": "Origi",
#                 "tweet_volume": 70923
#             },
#             {
#                 "name": "Richarlison",
#                 "url": "http://twitter.com/search?q=Richarlison",
#                 "promoted_content": null,
#                 "query": "Richarlison",
#                 "tweet_volume": 30630
#             },
#             {
#                 "name": "Klay",
#                 "url": "http://twitter.com/search?q=Klay",
#                 "promoted_content": null,
#                 "query": "Klay",
#                 "tweet_volume": 27508
#             },
#             {
#                 "name": "Milan",
#                 "url": "http://twitter.com/search?q=Milan",
#                 "promoted_content": null,
#                 "query": "Milan",
#                 "tweet_volume": 78606
#             },
#             {
#                 "name": "Vive la France",
#                 "url": "http://twitter.com/search?q=%22Vive+la+France%22",
#                 "promoted_content": null,
#                 "query": "%22Vive+la+France%22",
#                 "tweet_volume": 37518
#             },
#             {
#                 "name": "Pickford",
#                 "url": "http://twitter.com/search?q=Pickford",
#                 "promoted_content": null,
#                 "query": "Pickford",
#                 "tweet_volume": 24164
#             },
#             {
#                 "name": "Matip",
#                 "url": "http://twitter.com/search?q=Matip",
#                 "promoted_content": null,
#                 "query": "Matip",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Frexit",
#                 "url": "http://twitter.com/search?q=Frexit",
#                 "promoted_content": null,
#                 "query": "Frexit",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Slovenia",
#                 "url": "http://twitter.com/search?q=Slovenia",
#                 "promoted_content": null,
#                 "query": "Slovenia",
#                 "tweet_volume": 31716
#             },
#             {
#                 "name": "ONE OF US",
#                 "url": "http://twitter.com/search?q=%22ONE+OF+US%22",
#                 "promoted_content": null,
#                 "query": "%22ONE+OF+US%22",
#                 "tweet_volume": 109352
#             },
#             {
#                 "name": "Team of the Season",
#                 "url": "http://twitter.com/search?q=%22Team+of+the+Season%22",
#                 "promoted_content": null,
#                 "query": "%22Team+of+the+Season%22",
#                 "tweet_volume": 11416
#             },
#             {
#                 "name": "Anfield",
#                 "url": "http://twitter.com/search?q=Anfield",
#                 "promoted_content": null,
#                 "query": "Anfield",
#                 "tweet_volume": 30768
#             },
#             {
#                 "name": "Hyland",
#                 "url": "http://twitter.com/search?q=Hyland",
#                 "promoted_content": null,
#                 "query": "Hyland",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Tonali",
#                 "url": "http://twitter.com/search?q=Tonali",
#                 "promoted_content": null,
#                 "query": "Tonali",
#                 "tweet_volume": 16011
#             },
#             {
#                 "name": "Diaz",
#                 "url": "http://twitter.com/search?q=Diaz",
#                 "promoted_content": null,
#                 "query": "Diaz",
#                 "tweet_volume": 117375
#             },
#             {
#                 "name": "Carragher",
#                 "url": "http://twitter.com/search?q=Carragher",
#                 "promoted_content": null,
#                 "query": "Carragher",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "42% of French",
#                 "url": "http://twitter.com/search?q=%2242%25+of+French%22",
#                 "promoted_content": null,
#                 "query": "%2242%25+of+French%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Rigged",
#                 "url": "http://twitter.com/search?q=Rigged",
#                 "promoted_content": null,
#                 "query": "Rigged",
#                 "tweet_volume": 23456
#             },
#             {
#                 "name": "Lampard",
#                 "url": "http://twitter.com/search?q=Lampard",
#                 "promoted_content": null,
#                 "query": "Lampard",
#                 "tweet_volume": 22608
#             },
#             {
#                 "name": "poch",
#                 "url": "http://twitter.com/search?q=poch",
#                 "promoted_content": null,
#                 "query": "poch",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Melenchon",
#                 "url": "http://twitter.com/search?q=Melenchon",
#                 "promoted_content": null,
#                 "query": "Melenchon",
#                 "tweet_volume": 121551
#             },
#             {
#                 "name": "Matt Lucas",
#                 "url": "http://twitter.com/search?q=%22Matt+Lucas%22",
#                 "promoted_content": null,
#                 "query": "%22Matt+Lucas%22",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-04-24T22:20:30Z",
#         "created_at": "2022-04-20T05:45:31Z",
#         "locations": [
#             {
#                 "name": "London",
#                 "woeid": 44418
#             }
#         ]
#     }
# ]

# %%
# search for Paris
paris_trends = twitter_api.trends.place(_id = 615702)

# view JSON output
print(json.dumps(paris_trends, indent = 4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Marine",
#                 "url": "http://twitter.com/search?q=Marine",
#                 "promoted_content": null,
#                 "query": "Marine",
#                 "tweet_volume": 358281
#             },
#             {
#                 "name": "LePen",
#                 "url": "http://twitter.com/search?q=LePen",
#                 "promoted_content": null,
#                 "query": "LePen",
#                 "tweet_volume": 546066
#             },
#             {
#                 "name": "#5ansdeplus",
#                 "url": "http://twitter.com/search?q=%235ansdeplus",
#                 "promoted_content": null,
#                 "query": "%235ansdeplus",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#avecvous",
#                 "url": "http://twitter.com/search?q=%23avecvous",
#                 "promoted_content": null,
#                 "query": "%23avecvous",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Chirac",
#                 "url": "http://twitter.com/search?q=Chirac",
#                 "promoted_content": null,
#                 "query": "Chirac",
#                 "tweet_volume": 12153
#             },
#             {
#                 "name": "#melanchon",
#                 "url": "http://twitter.com/search?q=%23melanchon",
#                 "promoted_content": null,
#                 "query": "%23melanchon",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#GiletsJaunes",
#                 "url": "http://twitter.com/search?q=%23GiletsJaunes",
#                 "promoted_content": null,
#                 "query": "%23GiletsJaunes",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Jean Castex",
#                 "url": "http://twitter.com/search?q=%22Jean+Castex%22",
#                 "promoted_content": null,
#                 "query": "%22Jean+Castex%22",
#                 "tweet_volume": 12451
#             },
#             {
#                 "name": "#Elysee2022",
#                 "url": "http://twitter.com/search?q=%23Elysee2022",
#                 "promoted_content": null,
#                 "query": "%23Elysee2022",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Mayotte",
#                 "url": "http://twitter.com/search?q=Mayotte",
#                 "promoted_content": null,
#                 "query": "Mayotte",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Blanquer",
#                 "url": "http://twitter.com/search?q=Blanquer",
#                 "promoted_content": null,
#                 "query": "Blanquer",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Abstention",
#                 "url": "http://twitter.com/search?q=Abstention",
#                 "promoted_content": null,
#                 "query": "Abstention",
#                 "tweet_volume": 40391
#             },
#             {
#                 "name": "Front National",
#                 "url": "http://twitter.com/search?q=%22Front+National%22",
#                 "promoted_content": null,
#                 "query": "%22Front+National%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "RTBF",
#                 "url": "http://twitter.com/search?q=RTBF",
#                 "promoted_content": null,
#                 "query": "RTBF",
#                 "tweet_volume": 10562
#             },
#             {
#                 "name": "Arte",
#                 "url": "http://twitter.com/search?q=Arte",
#                 "promoted_content": null,
#                 "query": "Arte",
#                 "tweet_volume": 79606
#             },
#             {
#                 "name": "Gerson",
#                 "url": "http://twitter.com/search?q=Gerson",
#                 "promoted_content": null,
#                 "query": "Gerson",
#                 "tweet_volume": 16095
#             },
#             {
#                 "name": "Rayo",
#                 "url": "http://twitter.com/search?q=Rayo",
#                 "promoted_content": null,
#                 "query": "Rayo",
#                 "tweet_volume": 70017
#             },
#             {
#                 "name": "Valls",
#                 "url": "http://twitter.com/search?q=Valls",
#                 "promoted_content": null,
#                 "query": "Valls",
#                 "tweet_volume": 13099
#             },
#             {
#                 "name": "Reims",
#                 "url": "http://twitter.com/search?q=Reims",
#                 "promoted_content": null,
#                 "query": "Reims",
#                 "tweet_volume": 17409
#             },
#             {
#                 "name": "Rachida Dati",
#                 "url": "http://twitter.com/search?q=%22Rachida+Dati%22",
#                 "promoted_content": null,
#                 "query": "%22Rachida+Dati%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Klay",
#                 "url": "http://twitter.com/search?q=Klay",
#                 "promoted_content": null,
#                 "query": "Klay",
#                 "tweet_volume": 27652
#             },
#             {
#                 "name": "champ de mars",
#                 "url": "http://twitter.com/search?q=%22champ+de+mars%22",
#                 "promoted_content": null,
#                 "query": "%22champ+de+mars%22",
#                 "tweet_volume": 16385
#             },
#             {
#                 "name": "Marseillaise",
#                 "url": "http://twitter.com/search?q=Marseillaise",
#                 "promoted_content": null,
#                 "query": "Marseillaise",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "France 2",
#                 "url": "http://twitter.com/search?q=%22France+2%22",
#                 "promoted_content": null,
#                 "query": "%22France+2%22",
#                 "tweet_volume": 51169
#             },
#             {
#                 "name": "Xavi",
#                 "url": "http://twitter.com/search?q=Xavi",
#                 "promoted_content": null,
#                 "query": "Xavi",
#                 "tweet_volume": 57585
#             },
#             {
#                 "name": "Lanterne",
#                 "url": "http://twitter.com/search?q=Lanterne",
#                 "promoted_content": null,
#                 "query": "Lanterne",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Gavi",
#                 "url": "http://twitter.com/search?q=Gavi",
#                 "promoted_content": null,
#                 "query": "Gavi",
#                 "tweet_volume": 19274
#             },
#             {
#                 "name": "Mandanda",
#                 "url": "http://twitter.com/search?q=Mandanda",
#                 "promoted_content": null,
#                 "query": "Mandanda",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Vive la France",
#                 "url": "http://twitter.com/search?q=%22Vive+la+France%22",
#                 "promoted_content": null,
#                 "query": "%22Vive+la+France%22",
#                 "tweet_volume": 37550
#             },
#             {
#                 "name": "Milik",
#                 "url": "http://twitter.com/search?q=Milik",
#                 "promoted_content": null,
#                 "query": "Milik",
#                 "tweet_volume": 13637
#             },
#             {
#                 "name": "Dans 5",
#                 "url": "http://twitter.com/search?q=%22Dans+5%22",
#                 "promoted_content": null,
#                 "query": "%22Dans+5%22",
#                 "tweet_volume": 31921
#             },
#             {
#                 "name": "Curry",
#                 "url": "http://twitter.com/search?q=Curry",
#                 "promoted_content": null,
#                 "query": "Curry",
#                 "tweet_volume": 71486
#             },
#             {
#                 "name": "Jokic",
#                 "url": "http://twitter.com/search?q=Jokic",
#                 "promoted_content": null,
#                 "query": "Jokic",
#                 "tweet_volume": 17110
#             },
#             {
#                 "name": "Hyland",
#                 "url": "http://twitter.com/search?q=Hyland",
#                 "promoted_content": null,
#                 "query": "Hyland",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Dieng",
#                 "url": "http://twitter.com/search?q=Dieng",
#                 "promoted_content": null,
#                 "query": "Dieng",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Les Fran\u00e7ais",
#                 "url": "http://twitter.com/search?q=%22Les+Fran%C3%A7ais%22",
#                 "promoted_content": null,
#                 "query": "%22Les+Fran%C3%A7ais%22",
#                 "tweet_volume": 135193
#             },
#             {
#                 "name": "Denver",
#                 "url": "http://twitter.com/search?q=Denver",
#                 "promoted_content": null,
#                 "query": "Denver",
#                 "tweet_volume": 22446
#             },
#             {
#                 "name": "raquel garrido",
#                 "url": "http://twitter.com/search?q=%22raquel+garrido%22",
#                 "promoted_content": null,
#                 "query": "%22raquel+garrido%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Cl\u00e9mentine Autain",
#                 "url": "http://twitter.com/search?q=%22Cl%C3%A9mentine+Autain%22",
#                 "promoted_content": null,
#                 "query": "%22Cl%C3%A9mentine+Autain%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ferran",
#                 "url": "http://twitter.com/search?q=Ferran",
#                 "promoted_content": null,
#                 "query": "Ferran",
#                 "tweet_volume": 17573
#             },
#             {
#                 "name": "Tour Eiffel",
#                 "url": "http://twitter.com/search?q=%22Tour+Eiffel%22",
#                 "promoted_content": null,
#                 "query": "%22Tour+Eiffel%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Encore 5",
#                 "url": "http://twitter.com/search?q=%22Encore+5%22",
#                 "promoted_content": null,
#                 "query": "%22Encore+5%22",
#                 "tweet_volume": 25104
#             },
#             {
#                 "name": "Les 58%",
#                 "url": "http://twitter.com/search?q=%22Les+58%25%22",
#                 "promoted_content": null,
#                 "query": "%22Les+58%25%22",
#                 "tweet_volume": 19476
#             },
#             {
#                 "name": "Nuggets",
#                 "url": "http://twitter.com/search?q=Nuggets",
#                 "promoted_content": null,
#                 "query": "Nuggets",
#                 "tweet_volume": 30836
#             },
#             {
#                 "name": "Aux Armes",
#                 "url": "http://twitter.com/search?q=%22Aux+Armes%22",
#                 "promoted_content": null,
#                 "query": "%22Aux+Armes%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Pompidou",
#                 "url": "http://twitter.com/search?q=Pompidou",
#                 "promoted_content": null,
#                 "query": "Pompidou",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Les 42%",
#                 "url": "http://twitter.com/search?q=%22Les+42%25%22",
#                 "promoted_content": null,
#                 "query": "%22Les+42%25%22",
#                 "tweet_volume": 25377
#             },
#             {
#                 "name": "Warriors",
#                 "url": "http://twitter.com/search?q=Warriors",
#                 "promoted_content": null,
#                 "query": "Warriors",
#                 "tweet_volume": 157992
#             },
#             {
#                 "name": "Gueye",
#                 "url": "http://twitter.com/search?q=Gueye",
#                 "promoted_content": null,
#                 "query": "Gueye",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Camp Nou",
#                 "url": "http://twitter.com/search?q=%22Camp+Nou%22",
#                 "promoted_content": null,
#                 "query": "%22Camp+Nou%22",
#                 "tweet_volume": 26749
#             }
#         ],
#         "as_of": "2022-04-24T22:21:29Z",
#         "created_at": "2022-04-24T05:17:37Z",
#         "locations": [
#             {
#                 "name": "Paris",
#                 "woeid": 615702
#             }
#         ]
#     }
# ]

# %% [markdown]
# #### Common topics between cities

# %%
# find common topics
london_trends_list = [trend['name'] for trend in london_trends[0]['trends']]

# view output
print(london_trends_list)
# Out:
# ['#HarshRealityNosis', 'Brennan Johnson', '#CelebsForSmallBiz', 'Championship', 'Wilbur', 'Conte', 'Leeds', 'attwell', 'Merseyside', 'Reds', 'Paul Mitchell', 'Souness', 'Holgate', 'Allan', 'Andy Robertson', 'Goodison', 'Levy', '#JusticeForJohhnyDepp', 'Panthers', 'Macron', 'Le Pen', 'Everton', '#Grace', '#SASWhoDaresWins', 'Ranboo', 'Gordon', 'The French', 'Origi', 'Richarlison', 'Klay', 'Milan', 'Vive la France', 'Pickford', 'Matip', 'Frexit', 'Slovenia', 'ONE OF US', 'Team of the Season', 'Anfield', 'Hyland', 'Tonali', 'Diaz', 'Carragher', '42% of French', 'Rigged', 'Lampard', 'poch', 'Melenchon', 'Matt Lucas']

# %%
# find common topics
paris_trends_list = [trend['name'] for trend in paris_trends[0]['trends']]

# view output
print(paris_trends_list)
# Out:
# ['Marine', 'LePen', '#5ansdeplus', '#avecvous', 'Chirac', '#melanchon', '#GiletsJaunes', 'Jean Castex', '#Elysee2022', 'Mayotte', 'Blanquer', 'Abstention', 'Front National', 'RTBF', 'Arte', 'Gerson', 'Rayo', 'Valls', 'Reims', 'Rachida Dati', 'Klay', 'champ de mars', 'Marseillaise', 'France 2', 'Xavi', 'Lanterne', 'Gavi', 'Mandanda', 'Vive la France', 'Milik', 'Dans 5', 'Curry', 'Jokic', 'Hyland', 'Dieng', 'Les Français', 'Denver', 'raquel garrido', 'Clémentine Autain', 'Ferran', 'Tour Eiffel', 'Encore 5', 'Les 58%', 'Nuggets', 'Aux Armes', 'Pompidou', 'Les 42%', 'Warriors', 'Gueye', 'Camp Nou']

# %%
# find trends between cities
london_trends_set = set(london_trends_list)
paris_trends_set = set(paris_trends_list)

# set variable
common_trends = london_trends_set.intersection(paris_trends_set)

# view output
print(common_trends)
# Out:
# {'Vive la France', 'Hyland', 'Klay'}

# %% [markdown]
# ### Search for tweets

# %% [markdown]
# #### Step 1

# %%
# search a common trend
v = '#Vive la France'

# set count to 100
Count = 100

# %%
# read some tweets
search_results = twitter_api.search.tweets(q = v, count = 100)

statuses = search_results['statuses']

# %%
# create loop statement
for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # no more results when next_results doesn't exist
        break
        
# create a dictionary from next_results
kwargs = dict([kv.split('=') for kv in next_results[1:].split('&')])

search_results = twitter_api.search.tweets(**kwargs)
statuses += search_results['statuses']

# print output as JSON
print(json.dumps(statuses[1], indent = 1))
# Out:
# Length of statuses 27
# Length of statuses 27
# Length of statuses 27
# Length of statuses 27
# Length of statuses 27
# {
#  "created_at": "Sun Apr 24 21:55:26 +0000 2022",
#  "id": 1518347911997886464,
#  "id_str": "1518347911997886464",
#  "text": "@EmmanuelMacron To the people of France \ud83c\uddeb\ud83c\uddf7 #Vive la France https://t.co/u2mRxc0oYN",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "Vive",
#     "indices": [
#      43,
#      48
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "EmmanuelMacron",
#     "name": "Emmanuel Macron",
#     "id": 1976143068,
#     "id_str": "1976143068",
#     "indices": [
#      0,
#      15
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1518347906125864969,
#     "id_str": "1518347906125864969",
#     "indices": [
#      59,
#      82
#     ],
#     "media_url": "http://pbs.twimg.com/tweet_video_thumb/FRJBYEYXIAkW5td.jpg",
#     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FRJBYEYXIAkW5td.jpg",
#     "url": "https://t.co/u2mRxc0oYN",
#     "display_url": "pic.twitter.com/u2mRxc0oYN",
#     "expanded_url": "https://twitter.com/mzceetee/status/1518347911997886464/photo/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 480,
#       "h": 320,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 480,
#       "h": 320,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 480,
#       "h": 320,
#       "resize": "fit"
#      }
#     }
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1518347906125864969,
#     "id_str": "1518347906125864969",
#     "indices": [
#      59,
#      82
#     ],
#     "media_url": "http://pbs.twimg.com/tweet_video_thumb/FRJBYEYXIAkW5td.jpg",
#     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FRJBYEYXIAkW5td.jpg",
#     "url": "https://t.co/u2mRxc0oYN",
#     "display_url": "pic.twitter.com/u2mRxc0oYN",
#     "expanded_url": "https://twitter.com/mzceetee/status/1518347911997886464/photo/1",
#     "type": "animated_gif",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 480,
#       "h": 320,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 480,
#       "h": 320,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 480,
#       "h": 320,
#       "resize": "fit"
#      }
#     },
#     "video_info": {
#      "aspect_ratio": [
#       3,
#       2
#      ],
#      "variants": [
#       {
#        "bitrate": 0,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/tweet_video/FRJBYEYXIAkW5td.mp4"
#       }
#      ]
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": 1518312328248410112,
#  "in_reply_to_status_id_str": "1518312328248410112",
#  "in_reply_to_user_id": 1976143068,
#  "in_reply_to_user_id_str": "1976143068",
#  "in_reply_to_screen_name": "EmmanuelMacron",
#  "user": {
#   "id": 262466303,
#   "id_str": "262466303",
#   "name": "~Christina~",
#   "screen_name": "mzceetee",
#   "location": "Good Ole USA",
#   "description": "fighting for morals &integrity back by eliminating the GQP , #Resist DO Not DM ,this is not https://t.co/S8FaCzlPMa",
#   "url": "https://t.co/nhf8ka7jDP",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/nhf8ka7jDP",
#       "expanded_url": "https://www.marchfortruth.info/",
#       "display_url": "marchfortruth.info",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": [
#      {
#       "url": "https://t.co/S8FaCzlPMa",
#       "expanded_url": "http://match.com",
#       "display_url": "match.com",
#       "indices": [
#        92,
#        115
#       ]
#      }
#     ]
#    }
#   },
#   "protected": false,
#   "followers_count": 2185,
#   "friends_count": 2155,
#   "listed_count": 9,
#   "created_at": "Tue Mar 08 03:03:09 +0000 2011",
#   "favourites_count": 391000,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 25568,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "0099B9",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/679360428464582656/xPykuby1_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/679360428464582656/xPykuby1_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/262466303/1589065042",
#   "profile_link_color": "0099B9",
#   "profile_sidebar_border_color": "5ED4DC",
#   "profile_sidebar_fill_color": "95E8EC",
#   "profile_text_color": "3C3940",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none",
#   "withheld_in_countries": []
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 1,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %% [markdown]
# #### Step 2

# %%
# check statuses
t = statuses[0]

# print the keys
t.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
# find the id
print(t['id'])

# view the output in text
print(t['text'])

# view entities
t['entities']
# Out:
# 1518353010933567488
# Thank you France! #France 2 #Vive la France #Macron #democracywins #FrenchElection2022 #Vive la France #France #MacronPresident
# {'hashtags': [{'text': 'France', 'indices': [18, 25]},
#   {'text': 'Vive', 'indices': [28, 33]},
#   {'text': 'Macron', 'indices': [44, 51]},
#   {'text': 'democracywins', 'indices': [52, 66]},
#   {'text': 'FrenchElection2022', 'indices': [67, 86]},
#   {'text': 'Vive', 'indices': [87, 92]},
#   {'text': 'France', 'indices': [103, 110]},
#   {'text': 'MacronPresident', 'indices': [111, 127]}],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': []}
