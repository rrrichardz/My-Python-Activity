# %% [markdown]
# ## Practical_Activity_5.2.8

# %% [markdown]
# ### 1. Import YAML file and libraries

# %%
# copy the YAML file and your Twitter keys over before you start to work
import yaml
from yaml.loader import SafeLoader
from twitter import *

# import the yaml file - remember to specify the whole path
twitter_creds = yaml.safe_load(open('twitter.yaml', 'r').read())

# pass your twitter credentials
twitter_api = Twitter(auth = OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))

# %%
# see if you are connected
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000002845CCF8E20>

# %%
# run a test with #python
python_tweets = twitter_api.search.tweets(q = '#python')

# view output
print(python_tweets)
# Out:
# {'statuses': [{'created_at': 'Sun Apr 24 23:07:12 +0000 2022', 'id': 1518365973258059778, 'id_str': '1518365973258059778', 'text': 'RT @Sheraj99: Roadmap for #DataScience #cybersecurity #BigData #Analytics #AI #MachineLearning #IoT #IIoT #PyTorch #Python #RStats #TensorF…', 'truncated': False, 'entities': {'hashtags': [{'text': 'DataScience', 'indices': [26, 38]}, {'text': 'cybersecurity', 'indices': [39, 53]}, {'text': 'BigData', 'indices': [54, 62]}, {'text': 'Analytics', 'indices': [63, 73]}, {'text': 'AI', 'indices': [74, 77]}, {'text': 'MachineLearning', 'indices': [78, 94]}, {'text': 'IoT', 'indices': [95, 99]}, {'text': 'IIoT', 'indices': [100, 105]}, {'text': 'PyTorch', 'indices': [106, 114]}, {'text': 'Python', 'indices': [115, 122]}, {'text': 'RStats', 'indices': [123, 130]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Sheraj99', 'name': 'Syeda Sheraj Ali', 'id': 268619848, 'id_str': '268619848', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">JavaGeekBot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1423655520196435969, 'id_str': '1423655520196435969', 'name': 'Java Geek Tech', 'screen_name': 'JavaGeekBot', 'location': '', 'description': 'Hey, I am a bot, I retweet #java. If interested, #Follow me.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1031, 'friends_count': 0, 'listed_count': 22, 'created_at': 'Fri Aug 06 14:49:11 +0000 2021', 'favourites_count': 27, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 144753, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1424283133420085250/OrW_pGUK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1424283133420085250/OrW_pGUK_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1423655520196435969/1628410459', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Apr 24 23:07:11 +0000 2022', 'id': 1518365967709085698, 'id_str': '1518365967709085698', 'text': 'Roadmap for #DataScience #cybersecurity #BigData #Analytics #AI #MachineLearning #IoT #IIoT #PyTorch #Python… https://t.co/QporZD4Q9j', 'truncated': True, 'entities': {'hashtags': [{'text': 'DataScience', 'indices': [12, 24]}, {'text': 'cybersecurity', 'indices': [25, 39]}, {'text': 'BigData', 'indices': [40, 48]}, {'text': 'Analytics', 'indices': [49, 59]}, {'text': 'AI', 'indices': [60, 63]}, {'text': 'MachineLearning', 'indices': [64, 80]}, {'text': 'IoT', 'indices': [81, 85]}, {'text': 'IIoT', 'indices': [86, 91]}, {'text': 'PyTorch', 'indices': [92, 100]}, {'text': 'Python', 'indices': [101, 108]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QporZD4Q9j', 'expanded_url': 'https://twitter.com/i/web/status/1518365967709085698', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter  ...

# %% [markdown]
# ### 2. Identify New York and London

# %%
# determine worldwide trends
trends_worldwide = twitter_api.trends.available()

# how many trends available
print(len(trends_worldwide))

# example of trends_worldwide
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %% [markdown]
# #### New York

# %%
# find New York
our_city = 'New York'

# create variable
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# view output
print(len(list_of_names_our_city))

# use index to find New York
print(list_of_names_our_city[0])

# list of where on earth identifies (woeid)
list_of_names_our_city[0]['woeid']
# Out:
# 1
# {'name': 'New York', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/2459115', 'parentid': 23424977, 'country': 'United States', 'woeid': 2459115, 'countryCode': 'US'}
# 2459115

# %% [markdown]
# #### London

# %%
# find London
our_city_2 = 'London'

# create variable
list_of_names_our_city_2 = [_ for _ in trends_worldwide if _['name'] == our_city_2]

# view output
print(len(list_of_names_our_city_2))

# use index to find London
print(list_of_names_our_city_2[0])

# list of where on earch identifies (woeid)
list_of_names_our_city_2[0]['woeid']
# Out:
# 1
# {'name': 'London', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/44418', 'parentid': 23424975, 'country': 'United Kingdom', 'woeid': 44418, 'countryCode': 'GB'}
# 44418

# %% [markdown]
# ### 3. Common trends

# %% [markdown]
# #### New York

# %%
# look at trends in New York
our_city_trends = twitter_api.trends.place(_id = list_of_names_our_city[0]['woeid'])

# view output
our_city_trends
# Out:
# [{'trends': [{'name': 'Tylor Megill',
#     'url': 'http://twitter.com/search?q=%22Tylor+Megill%22',
#     'promoted_content': None,
#     'query': '%22Tylor+Megill%22',
#     'tweet_volume': None},
#    {'name': '#RBNY',
#     'url': 'http://twitter.com/search?q=%23RBNY',
#     'promoted_content': None,
#     'query': '%23RBNY',
#     'tweet_volume': None},
#    {'name': '#FrenchElections2022',
#     'url': 'http://twitter.com/search?q=%23FrenchElections2022',
#     'promoted_content': None,
#     'query': '%23FrenchElections2022',
#     'tweet_volume': 16188},
#    {'name': 'Vive la France',
#     'url': 'http://twitter.com/search?q=%22Vive+la+France%22',
#     'promoted_content': None,
#     'query': '%22Vive+la+France%22',
#     'tweet_volume': 39193},
#    {'name': '#RepBX',
#     'url': 'http://twitter.com/search?q=%23RepBX',
#     'promoted_content': None,
#     'query': '%23RepBX',
#     'tweet_volume': None},
#    {'name': 'Tory',
#     'url': 'http://twitter.com/search?q=Tory',
#     'promoted_content': None,
#     'query': 'Tory',
#     'tweet_volume': 101689},
#    {'name': 'Staten Island',
#     'url': 'http://twitter.com/search?q=%22Staten+Island%22',
#     'promoted_content': None,
#     'query': '%22Staten+Island%22',
#     'tweet_volume': None},
#    {'name': '#WithYou',
#     'url': 'http://twitter.com/search?q=%23WithYou',
#     'promoted_content': None,
#     'query': '%23WithYou',
#     'tweet_volume': 1531136},
#    {'name': 'Everton',
#     'url': 'http://twitter.com/search?q=Everton',
#     'promoted_content': None,
#     'query': 'Everton',
#     'tweet_volume': 208744},
#    {'name': 'Guardians',
#     'url': 'http://twitter.com/search?q=Guardians',
#     'promoted_content': None,
#     'query': 'Guardians',
#     'tweet_volume': 15078},
#    {'name': 'Jokic',
#     'url': 'http://twitter.com/search?q=Jokic',
#     'promoted_content': None,
#     'query': 'Jokic',
#     'tweet_volume': 30424},
#    {'name': 'Ben Simmons',
#     'url': 'http://twitter.com/search?q=%22Ben+Simmons%22',
#     'promoted_content': None,
#     'query': '%22Ben+Simmons%22',
#     'tweet_volume': 82438},
#    {'name': 'Steph',
#     'url': 'http://twitter.com/search?q=Steph',
#     'promoted_content': None,
#     'query': 'Steph',
#     'tweet_volume': 71291},
#    {'name': 'Klay',
#     'url': 'http://twitter.com/search?q=Klay',
#     'promoted_content': None,
#     'query': 'Klay',
#     'tweet_volume': 31342},
#    {'name': 'Wiggins',
#     'url': 'http://twitter.com/search?q=Wiggins',
#     'promoted_content': None,
#     'query': 'Wiggins',
#     'tweet_volume': 15265},
#    {'name': 'Barton',
#     'url': 'http://twitter.com/search?q=Barton',
#     'promoted_content': None,
#     'query': 'Barton',
#     'tweet_volume': None},
#    {'name': '#GSWvsDEN',
#     'url': 'http://twitter.com/search?q=%23GSWvsDEN',
#     'promoted_content': None,
#     'query': '%23GSWvsDEN',
#     'tweet_volume': None},
#    {'name': 'Nuggets',
#     'url': 'http://twitter.com/search?q=Nuggets',
#     'promoted_content': None,
#     'query': 'Nuggets',
#     'tweet_volume': 44845},
#    {'name': 'Macron',
#     'url': 'http://twitter.com/search?q=Macron',
#     'promoted_content': None,
#     'query': 'Macron',
#     'tweet_volume': 1301415},
#    {'name': 'Steve Kerr',
#     'url': 'http://twitter.com/search?q=%22Steve+Kerr%22',
#     'promoted_content': None,
#     'query': '%22Steve+Kerr%22',
#     'tweet_volume': None},
#    {'name': 'Draymond',
#     'url': 'http://twitter.com/search?q=Draymond',
#     'promoted_content': None,
#     'query': 'Draymond',
#     'tweet_volume': 15317},
#    {'name': 'Buxton',
#     'url': 'http://twitter.com/search?q=Buxton',
#     'promoted_content': None,
#     'query': 'Buxton',
#     'tweet_volume': None},
#    {'name': 'Ranboo',
#     'url': 'http://twitter.com/search?q=Ranboo',
#     'promoted_content': None,
#     'query': 'Ranboo',
#     'tweet_volume': 80957},
#    {'name': 'Denver',
#     'url': 'http://twitter.com/search?q=Denver',
#     'promoted_content': None,
#     'query': 'Denver',
#     'tweet_volume': 27773},
#    {'name': 'Le Pen',
#     'url': 'http://twitter.com/search?q=%22Le+Pen%22',
#     'promoted_content': None,
#     'query': '%22Le+Pen%22',
#     'tweet_volume': 158732},
#    {'name': 'IPAs',
#     'url': 'http://twitter.com/search?q=IPAs',
#     'promoted_content': None,
#     'query': 'IPAs',
#     'tweet_volume': None},
#    {'name': 'Ross Chastain',
#     'url': 'http://twitter.com/search?q=%22Ross+Chastain%22',
#     'promoted_content': None,
#     'query': '%22Ross+Chastain%22',
#     'tweet_volume': None},
#    {'name': 'Otto Porter',
#     'url': 'http://twitter.com/search?q=%22Otto+Porter%22',
#     'promoted_content': None,
#     'query': '%22Otto+Porter%22',
#     'tweet_volume': None},
#    {'name': 'Bones Hyland',
#     'url': 'http://twitter.com/search?q=%22Bones+Hyland%22',
#     'promoted_content': None,
#     'query': '%22Bones+Hyland%22',
#     'tweet_volume': None},
#    {'name': 'Larson',
#     'url': 'http://twitter.com/search?q=Larson',
#     'promoted_content': None,
#     'query': 'Larson',
#     'tweet_volume': None},
#    {'name': 'Austin Rivers',
#     'url': 'http://twitter.com/search?q=%22Austin+Rivers%22',
#     'promoted_content': None,
#     'query': '%22Austin+Rivers%22',
#     'tweet_volume': None},
#    {'name': 'Newt',
#     'url': 'http://twitter.com/search?q=Newt',
#     'promoted_content': None,
#     'query': 'Newt',
#     'tweet_volume': None},
#    {'name': 'Publix',
#     'url': 'http://twitter.com/search?q=Publix',
#     'promoted_content': None,
#     'query': 'Publix',
#     'tweet_volume': 22216},
#    {'name': 'Peña',
#     'url': 'http://twitter.com/search?q=Pe%C3%B1a',
#     'promoted_content': None,
#     'query': 'Pe%C3%B1a',
#     'tweet_volume': 149391},
#    {'name': 'Bubba',
#     'url': 'http://twitter.com/search?q=Bubba',
#     'promoted_content': None,
#     'query': 'Bubba',
#     'tweet_volume': None},
#    {'name': 'Travis Hunter',
#     'url': 'http://twitter.com/search?q=%22Travis+Hunter%22',
#     'promoted_content': None,
#     'query': '%22Travis+Hunter%22',
#     'tweet_volume': None},
#    {'name': 'Monte Morris',
#     'url': 'http://twitter.com/search?q=%22Monte+Morris%22',
#     'promoted_content': None,
#     'query': '%22Monte+Morris%22',
#     'tweet_volume': None},
#    {'name': 'bellinger',
#     'url': 'http://twitter.com/search?q=bellinger',
#     'promoted_content': None,
#     'query': 'bellinger',
#     'tweet_volume': None},
#    {'name': 'Boogie',
#     'url': 'http://twitter.com/search?q=Boogie',
#     'promoted_content': None,
#     'query': 'Boogie',
#     'tweet_volume': None},
#    {'name': 'Grayson Allen',
#     'url': 'http://twitter.com/search?q=%22Grayson+Allen%22',
#     'promoted_content': None,
#     'query': '%22Grayson+Allen%22',
#     'tweet_volume': 14300},
#    {'name': 'Aaron Gordon',
#     'url': 'http://twitter.com/search?q=%22Aaron+Gordon%22',
#     'promoted_content': None,
#     'query': '%22Aaron+Gordon%22',
#     'tweet_volume': None},
#    {'name': 'Bednar',
#     'url': 'http://twitter.com/search?q=Bednar',
#     'promoted_content': None,
#     'query': 'Bednar',
#     'tweet_volume': None},
#    {'name': 'Erik Jones',
#     'url': 'http://twitter.com/search?q=%22Erik+Jones%22',
#     'promoted_content': None,
#     'query': '%22Erik+Jones%22',
#     'tweet_volume': None},
#    {'name': 'Xavi',
#     'url': 'http://twitter.com/search?q=Xavi',
#     'promoted_content': None,
#     'query': 'Xavi',
#     'tweet_volume': 64910},
#    {'name': 'Noah Cates',
#     'url': 'http://twitter.com/search?q=%22Noah+Cates%22',
#     'promoted_content': None,
#     'query': '%22Noah+Cates%22',
#     'tweet_volume': None},
#    {'name': 'Doris Burke',
#     'url': 'http://twitter.com/search?q=%22Doris+Burke%22',
#     'promoted_content': None,
#     'query': '%22Doris+Burke%22',
#     'tweet_volume': None},
#    {'name': 'Game 5',
#     'url': 'http://twitter.com/search?q=%22Game+5%22',
#     'promoted_content': None,
#     'query': '%22Game+5%22',
#     'tweet_volume': 55810},
#    {'name': 'Massless',
#     'url': 'http://twitter.com/search?q=Massless',
#     'promoted_content': None,
#     'query': 'Massless',
#     'tweet_volume': None},
#    {'name': 'Giannis',
#     'url': 'http://twitter.com/search?q=Giannis',
#     'promoted_content': None,
#     'query': 'Giannis',
#     'tweet_volume': 27441},
#    {'name': 'Kuminga',
#     'url': 'http://twitter.com/search?q=Kuminga',
#     'promoted_content': None,
#     'query': 'Kuminga',
#     'tweet_volume': None}],
#   'as_of': '2022-04-24T23:14:04Z',
#   'created_at': '2022-04-20T05:45:31Z',
#   'locations': [{'name': 'New York', 'woeid': 2459115}]}]

# %%
# look at output as DataFrame
# import Pandas
import pandas as pd

# create DataFrame
our_city_trends_pd = pd.DataFrame(our_city_trends[0]['trends'])

# view DataFrame
our_city_trends_pd
# Out:
#                     name                                                url  \
# 0           Tylor Megill     http://twitter.com/search?q=%22Tylor+Megill%22
# 1                  #RBNY                http://twitter.com/search?q=%23RBNY
# 2   #FrenchElections2022  http://twitter.com/search?q=%23FrenchElections...
# 3         Vive la France   http://twitter.com/search?q=%22Vive+la+France%22
# 4                 #RepBX               http://twitter.com/search?q=%23RepBX
# 5                   Tory                   http://twitter.com/search?q=Tory
# 6          Staten Island    http://twitter.com/search?q=%22Staten+Island%22
# 7               #WithYou             http://twitter.com/search?q=%23WithYou
# 8                Everton                http://twitter.com/search?q=Everton
# 9              Guardians              http://twitter.com/search?q=Guardians
# 10                 Jokic                  http://twitter.com/search?q=Jokic
# 11           Ben Simmons      http://twitter.com/search?q=%22Ben+Simmons%22
# 12                 Steph                  http://twitter.com/search?q=Steph
# 13                  Klay                   http://twitter.com/search?q=Klay
# 14               Wiggins                http://twitter.com/search?q=Wiggins
# 15                Barton                 http://twitter.com/search?q=Barton
# 16             #GSWvsDEN            http://twitter.com/search?q=%23GSWvsDEN
# 17               Nuggets                http://twitter.com/search?q=Nuggets
# 18                Macron                 http://twitter.com/search?q=Macron
# 19            Steve Kerr       http://twitter.com/search?q=%22Steve+Kerr%22
# 20              Draymond               http://twitter.com/search?q=Draymond
# 21                Buxton                 http://twitter.com/search?q=Buxton
# 22                Ranboo                 http://twitter.com/search?q=Ranboo
# 23                Denver                 http://twitter.com/search?q=Denver
# 24                Le Pen           http://twitter.com/search?q=%22Le+Pen%22
# 25                  IPAs                   http://twitter.com/search?q=IPAs
# 26         Ross Chastain    http://twitter.com/search?q=%22Ross+Chastain%22
# 27           Otto Porter      http://twitter.com/search?q=%22Otto+Porter%22
# 28          Bones Hyland     http://twitter.com/search?q=%22Bones+Hyland%22
# 29                Larson                 http://twitter.com/search?q=Larson
# 30         Austin Rivers    http://twitter.com/search?q=%22Austin+Rivers%22
# 31                  Newt                   http://twitter.com/search?q=Newt
# 32                Publix                 http://twitter.com/search?q=Publix
# 33                  Peña              http://twitter.com/search?q=Pe%C3%B1a
# 34                 Bubba                  http://twitter.com/search?q=Bubba
# 35         Travis Hunter    http://twitter.com/search?q=%22Travis+Hunter%22
# 36          Monte Morris     http://twitter.com/search?q=%22Monte+Morris%22
# 37             bellinger              http://twitter.com/search?q=bellinger
# 38                Boogie                 http://twitter.com/search?q=Boogie
# 39         Grayson Allen    http://twitter.com/search?q=%22Grayson+Allen%22
# 40          Aaron Gordon     http://twitter.com/search?q=%22Aaron+Gordon%22
# 41                Bednar                 http://twitter.com/search?q=Bednar
# 42            Erik Jones       http://twitter.com/search?q=%22Erik+Jones%22
# 43                  Xavi                   http://twitter.com/search?q=Xavi
# 44            Noah Cates       http://twitter.com/search?q=%22Noah+Cates%22
# 45           Doris Burke      http://twitter.com/search?q=%22Doris+Burke%22
# 46                Game 5           http://twitter.com/search?q=%22Game+5%22
# 47              Massless               http://twitter.com/search?q=Massless
# 48               Giannis                http://twitter.com/search?q=Giannis
# 49               Kuminga                http://twitter.com/search?q=Kuminga
#
#    promoted_content                   query  tweet_volume
# 0              None      %22Tylor+Megill%22           NaN
# 1              None                 %23RBNY           NaN
# 2              None  %23FrenchElections2022       16188.0
# 3              None    %22Vive+la+France%22       39193.0
# 4              None                %23RepBX           NaN
# 5              None                    Tory      101689.0
# 6              None     %22Staten+Island%22           NaN
# 7              None              %23WithYou     1531136.0
# 8              None                 Everton      208744.0
# 9              None               Guardians       15078.0
# 10             None                   Jokic       30424.0
# 11             None       %22Ben+Simmons%22       82438.0
# 12             None                   Steph       71291.0
# 13             None                    Klay       31342.0
# 14             None                 Wiggins       15265.0
# 15             None                  Barton           NaN
# 16             None             %23GSWvsDEN           NaN
# 17             None                 Nuggets       44845.0
# 18             None                  Macron     1301415.0
# 19             None        %22Steve+Kerr%22           NaN
# 20             None                Draymond       15317.0
# 21             None                  Buxton           NaN
# 22             None                  Ranboo       80957.0
# 23             None                  Denver       27773.0
# 24             None            %22Le+Pen%22      158732.0
# 25             None                    IPAs           NaN
# 26             None     %22Ross+Chastain%22           NaN
# 27             None       %22Otto+Porter%22           NaN
# 28             None      %22Bones+Hyland%22           NaN
# 29             None                  Larson           NaN
# 30             None     %22Austin+Rivers%22           NaN
# 31             None                    Newt           NaN
# 32             None                  Publix       22216.0
# 33             None               Pe%C3%B1a      149391.0
# 34             None                   Bubba           NaN
# 35             None     %22Travis+Hunter%22           NaN
# 36             None      %22Monte+Morris%22           NaN
# 37             None               bellinger           NaN
# 38             None                  Boogie           NaN
# 39             None     %22Grayson+Allen%22       14300.0
# 40             None      %22Aaron+Gordon%22           NaN
# 41             None                  Bednar           NaN
# 42             None        %22Erik+Jones%22           NaN
# 43             None                    Xavi       64910.0
# 44             None        %22Noah+Cates%22           NaN
# 45             None       %22Doris+Burke%22           NaN
# 46             None            %22Game+5%22       55810.0
# 47             None                Massless           NaN
# 48             None                 Giannis       27441.0
# 49             None                 Kuminga           NaN

# %%
# narrow list down to 50,000 tweets
our_city_trends_over50k_pd = our_city_trends_pd[our_city_trends_pd['tweet_volume'] \
> 50000] \
.sort_values('tweet_volume', ascending = False)

# view the output
print(our_city_trends_over50k_pd.shape)
our_city_trends_over50k_pd
# Out:
# (11, 5)
#            name                                            url  \
# 7      #WithYou         http://twitter.com/search?q=%23WithYou
# 18       Macron             http://twitter.com/search?q=Macron
# 8       Everton            http://twitter.com/search?q=Everton
# 24       Le Pen       http://twitter.com/search?q=%22Le+Pen%22
# 33         Peña          http://twitter.com/search?q=Pe%C3%B1a
# 5          Tory               http://twitter.com/search?q=Tory
# 11  Ben Simmons  http://twitter.com/search?q=%22Ben+Simmons%22
# 22       Ranboo             http://twitter.com/search?q=Ranboo
# 12        Steph              http://twitter.com/search?q=Steph
# 43         Xavi               http://twitter.com/search?q=Xavi
# 46       Game 5       http://twitter.com/search?q=%22Game+5%22
#
#    promoted_content              query  tweet_volume
# 7              None         %23WithYou     1531136.0
# 18             None             Macron     1301415.0
# 8              None            Everton      208744.0
# 24             None       %22Le+Pen%22      158732.0
# 33             None          Pe%C3%B1a      149391.0
# 5              None               Tory      101689.0
# 11             None  %22Ben+Simmons%22       82438.0
# 22             None             Ranboo       80957.0
# 12             None              Steph       71291.0
# 43             None               Xavi       64910.0
# 46             None       %22Game+5%22       55810.0

# %%
# save output as CSV file
our_city_trends_over50k_pd.to_csv('NY_our_city_trends_over50k.csv', index=False)

# %% [markdown]
# #### London

# %%
# look at trends in London
our_city_trends_2 = twitter_api.trends.place(_id = list_of_names_our_city_2[0]['woeid'])

# view output
our_city_trends_2
# Out:
# [{'trends': [{'name': '#HarshRealityNosis',
#     'url': 'http://twitter.com/search?q=%23HarshRealityNosis',
#     'promoted_content': None,
#     'query': '%23HarshRealityNosis',
#     'tweet_volume': None},
#    {'name': 'Wilbur',
#     'url': 'http://twitter.com/search?q=Wilbur',
#     'promoted_content': None,
#     'query': 'Wilbur',
#     'tweet_volume': 10813},
#    {'name': 'Merseyside',
#     'url': 'http://twitter.com/search?q=Merseyside',
#     'promoted_content': None,
#     'query': 'Merseyside',
#     'tweet_volume': 35694},
#    {'name': 'Martin Tyler',
#     'url': 'http://twitter.com/search?q=%22Martin+Tyler%22',
#     'promoted_content': None,
#     'query': '%22Martin+Tyler%22',
#     'tweet_volume': None},
#    {'name': 'Reds',
#     'url': 'http://twitter.com/search?q=Reds',
#     'promoted_content': None,
#     'query': 'Reds',
#     'tweet_volume': 40585},
#    {'name': 'Paul Mitchell',
#     'url': 'http://twitter.com/search?q=%22Paul+Mitchell%22',
#     'promoted_content': None,
#     'query': '%22Paul+Mitchell%22',
#     'tweet_volume': None},
#    {'name': 'Souness',
#     'url': 'http://twitter.com/search?q=Souness',
#     'promoted_content': None,
#     'query': 'Souness',
#     'tweet_volume': None},
#    {'name': 'Giannis',
#     'url': 'http://twitter.com/search?q=Giannis',
#     'promoted_content': None,
#     'query': 'Giannis',
#     'tweet_volume': 27470},
#    {'name': 'Andy Robertson',
#     'url': 'http://twitter.com/search?q=%22Andy+Robertson%22',
#     'promoted_content': None,
#     'query': '%22Andy+Robertson%22',
#     'tweet_volume': None},
#    {'name': 'Allan',
#     'url': 'http://twitter.com/search?q=Allan',
#     'promoted_content': None,
#     'query': 'Allan',
#     'tweet_volume': 19500},
#    {'name': 'Goodison',
#     'url': 'http://twitter.com/search?q=Goodison',
#     'promoted_content': None,
#     'query': 'Goodison',
#     'tweet_volume': None},
#    {'name': 'Panthers',
#     'url': 'http://twitter.com/search?q=Panthers',
#     'promoted_content': None,
#     'query': 'Panthers',
#     'tweet_volume': 14417},
#    {'name': 'Basic Instinct',
#     'url': 'http://twitter.com/search?q=%22Basic+Instinct%22',
#     'promoted_content': None,
#     'query': '%22Basic+Instinct%22',
#     'tweet_volume': 12984},
#    {'name': 'Macron',
#     'url': 'http://twitter.com/search?q=Macron',
#     'promoted_content': None,
#     'query': 'Macron',
#     'tweet_volume': 1303360},
#    {'name': 'Le Pen',
#     'url': 'http://twitter.com/search?q=%22Le+Pen%22',
#     'promoted_content': None,
#     'query': '%22Le+Pen%22',
#     'tweet_volume': 567706},
#    {'name': 'Everton',
#     'url': 'http://twitter.com/search?q=Everton',
#     'promoted_content': None,
#     'query': 'Everton',
#     'tweet_volume': 208831},
#    {'name': 'Jokic',
#     'url': 'http://twitter.com/search?q=Jokic',
#     'promoted_content': None,
#     'query': 'Jokic',
#     'tweet_volume': 30603},
#    {'name': '#Grace',
#     'url': 'http://twitter.com/search?q=%23Grace',
#     'promoted_content': None,
#     'query': '%23Grace',
#     'tweet_volume': None},
#    {'name': '#forgotten80s',
#     'url': 'http://twitter.com/search?q=%23forgotten80s',
#     'promoted_content': None,
#     'query': '%23forgotten80s',
#     'tweet_volume': None},
#    {'name': 'Ranboo',
#     'url': 'http://twitter.com/search?q=Ranboo',
#     'promoted_content': None,
#     'query': 'Ranboo',
#     'tweet_volume': 81373},
#    {'name': '#SASWhoDaresWins',
#     'url': 'http://twitter.com/search?q=%23SASWhoDaresWins',
#     'promoted_content': None,
#     'query': '%23SASWhoDaresWins',
#     'tweet_volume': None},
#    {'name': 'The French',
#     'url': 'http://twitter.com/search?q=%22The+French%22',
#     'promoted_content': None,
#     'query': '%22The+French%22',
#     'tweet_volume': 142019},
#    {'name': 'Gordon',
#     'url': 'http://twitter.com/search?q=Gordon',
#     'promoted_content': None,
#     'query': 'Gordon',
#     'tweet_volume': 50695},
#    {'name': '#FrenchElections2022',
#     'url': 'http://twitter.com/search?q=%23FrenchElections2022',
#     'promoted_content': None,
#     'query': '%23FrenchElections2022',
#     'tweet_volume': 16212},
#    {'name': 'Wiggins',
#     'url': 'http://twitter.com/search?q=Wiggins',
#     'promoted_content': None,
#     'query': 'Wiggins',
#     'tweet_volume': 15308},
#    {'name': 'Klay',
#     'url': 'http://twitter.com/search?q=Klay',
#     'promoted_content': None,
#     'query': 'Klay',
#     'tweet_volume': 31448},
#    {'name': 'Steph',
#     'url': 'http://twitter.com/search?q=Steph',
#     'promoted_content': None,
#     'query': 'Steph',
#     'tweet_volume': 71468},
#    {'name': 'Origi',
#     'url': 'http://twitter.com/search?q=Origi',
#     'promoted_content': None,
#     'query': 'Origi',
#     'tweet_volume': 71980},
#    {'name': 'Vive la France',
#     'url': 'http://twitter.com/search?q=%22Vive+la+France%22',
#     'promoted_content': None,
#     'query': '%22Vive+la+France%22',
#     'tweet_volume': 39247},
#    {'name': 'Richarlison',
#     'url': 'http://twitter.com/search?q=Richarlison',
#     'promoted_content': None,
#     'query': 'Richarlison',
#     'tweet_volume': 30988},
#    {'name': 'Denver',
#     'url': 'http://twitter.com/search?q=Denver',
#     'promoted_content': None,
#     'query': 'Denver',
#     'tweet_volume': 27862},
#    {'name': 'Pickford',
#     'url': 'http://twitter.com/search?q=Pickford',
#     'promoted_content': None,
#     'query': 'Pickford',
#     'tweet_volume': 24818},
#    {'name': 'Milan',
#     'url': 'http://twitter.com/search?q=Milan',
#     'promoted_content': None,
#     'query': 'Milan',
#     'tweet_volume': 81035},
#    {'name': 'Warriors',
#     'url': 'http://twitter.com/search?q=Warriors',
#     'promoted_content': None,
#     'query': 'Warriors',
#     'tweet_volume': 179169},
#    {'name': 'Brennan Johnson',
#     'url': 'http://twitter.com/search?q=%22Brennan+Johnson%22',
#     'promoted_content': None,
#     'query': '%22Brennan+Johnson%22',
#     'tweet_volume': None},
#    {'name': 'Slovenia',
#     'url': 'http://twitter.com/search?q=Slovenia',
#     'promoted_content': None,
#     'query': 'Slovenia',
#     'tweet_volume': 35517},
#    {'name': 'Matip',
#     'url': 'http://twitter.com/search?q=Matip',
#     'promoted_content': None,
#     'query': 'Matip',
#     'tweet_volume': None},
#    {'name': 'Melenchon',
#     'url': 'http://twitter.com/search?q=Melenchon',
#     'promoted_content': None,
#     'query': 'Melenchon',
#     'tweet_volume': 126586},
#    {'name': 'Frexit',
#     'url': 'http://twitter.com/search?q=Frexit',
#     'promoted_content': None,
#     'query': 'Frexit',
#     'tweet_volume': None},
#    {'name': 'Rigged',
#     'url': 'http://twitter.com/search?q=Rigged',
#     'promoted_content': None,
#     'query': 'Rigged',
#     'tweet_volume': 25724},
#    {'name': '42% of French',
#     'url': 'http://twitter.com/search?q=%2242%25+of+French%22',
#     'promoted_content': None,
#     'query': '%2242%25+of+French%22',
#     'tweet_volume': None},
#    {'name': 'Hyland',
#     'url': 'http://twitter.com/search?q=Hyland',
#     'promoted_content': None,
#     'query': 'Hyland',
#     'tweet_volume': None},
#    {'name': 'Draymond',
#     'url': 'http://twitter.com/search?q=Draymond',
#     'promoted_content': None,
#     'query': 'Draymond',
#     'tweet_volume': 15342},
#    {'name': 'team of the season',
#     'url': 'http://twitter.com/search?q=%22team+of+the+season%22',
#     'promoted_content': None,
#     'query': '%22team+of+the+season%22',
#     'tweet_volume': 11854},
#    {'name': 'Tonali',
#     'url': 'http://twitter.com/search?q=Tonali',
#     'promoted_content': None,
#     'query': 'Tonali',
#     'tweet_volume': 17572},
#    {'name': 'Diaz',
#     'url': 'http://twitter.com/search?q=Diaz',
#     'promoted_content': None,
#     'query': 'Diaz',
#     'tweet_volume': 118930},
#    {'name': 'Anfield',
#     'url': 'http://twitter.com/search?q=Anfield',
#     'promoted_content': None,
#     'query': 'Anfield',
#     'tweet_volume': 31206},
#    {'name': 'ONE OF US',
#     'url': 'http://twitter.com/search?q=%22ONE+OF+US%22',
#     'promoted_content': None,
#     'query': '%22ONE+OF+US%22',
#     'tweet_volume': 108785},
#    {'name': 'Matt Lucas',
#     'url': 'http://twitter.com/search?q=%22Matt+Lucas%22',
#     'promoted_content': None,
#     'query': '%22Matt+Lucas%22',
#     'tweet_volume': None}],
#   'as_of': '2022-04-24T23:15:47Z',
#   'created_at': '2022-04-20T05:45:31Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
# look at output as a DataFrame
# import Pandas
import pandas as pd

# create DataFrame
our_city_trends_2_pd = pd.DataFrame(our_city_trends_2[0]['trends'])

# view DataFrame
our_city_trends_2_pd
# Out:
#                     name                                                url  \
# 0     #HarshRealityNosis   http://twitter.com/search?q=%23HarshRealityNosis
# 1                 Wilbur                 http://twitter.com/search?q=Wilbur
# 2             Merseyside             http://twitter.com/search?q=Merseyside
# 3           Martin Tyler     http://twitter.com/search?q=%22Martin+Tyler%22
# 4                   Reds                   http://twitter.com/search?q=Reds
# 5          Paul Mitchell    http://twitter.com/search?q=%22Paul+Mitchell%22
# 6                Souness                http://twitter.com/search?q=Souness
# 7                Giannis                http://twitter.com/search?q=Giannis
# 8         Andy Robertson   http://twitter.com/search?q=%22Andy+Robertson%22
# 9                  Allan                  http://twitter.com/search?q=Allan
# 10              Goodison               http://twitter.com/search?q=Goodison
# 11              Panthers               http://twitter.com/search?q=Panthers
# 12        Basic Instinct   http://twitter.com/search?q=%22Basic+Instinct%22
# 13                Macron                 http://twitter.com/search?q=Macron
# 14                Le Pen           http://twitter.com/search?q=%22Le+Pen%22
# 15               Everton                http://twitter.com/search?q=Everton
# 16                 Jokic                  http://twitter.com/search?q=Jokic
# 17                #Grace               http://twitter.com/search?q=%23Grace
# 18         #forgotten80s        http://twitter.com/search?q=%23forgotten80s
# 19                Ranboo                 http://twitter.com/search?q=Ranboo
# 20      #SASWhoDaresWins     http://twitter.com/search?q=%23SASWhoDaresWins
# 21            The French       http://twitter.com/search?q=%22The+French%22
# 22                Gordon                 http://twitter.com/search?q=Gordon
# 23  #FrenchElections2022  http://twitter.com/search?q=%23FrenchElections...
# 24               Wiggins                http://twitter.com/search?q=Wiggins
# 25                  Klay                   http://twitter.com/search?q=Klay
# 26                 Steph                  http://twitter.com/search?q=Steph
# 27                 Origi                  http://twitter.com/search?q=Origi
# 28        Vive la France   http://twitter.com/search?q=%22Vive+la+France%22
# 29           Richarlison            http://twitter.com/search?q=Richarlison
# 30                Denver                 http://twitter.com/search?q=Denver
# 31              Pickford               http://twitter.com/search?q=Pickford
# 32                 Milan                  http://twitter.com/search?q=Milan
# 33              Warriors               http://twitter.com/search?q=Warriors
# 34       Brennan Johnson  http://twitter.com/search?q=%22Brennan+Johnson%22
# 35              Slovenia               http://twitter.com/search?q=Slovenia
# 36                 Matip                  http://twitter.com/search?q=Matip
# 37             Melenchon              http://twitter.com/search?q=Melenchon
# 38                Frexit                 http://twitter.com/search?q=Frexit
# 39                Rigged                 http://twitter.com/search?q=Rigged
# 40         42% of French  http://twitter.com/search?q=%2242%25+of+French%22
# 41                Hyland                 http://twitter.com/search?q=Hyland
# 42              Draymond               http://twitter.com/search?q=Draymond
# 43    team of the season  http://twitter.com/search?q=%22team+of+the+sea...
# 44                Tonali                 http://twitter.com/search?q=Tonali
# 45                  Diaz                   http://twitter.com/search?q=Diaz
# 46               Anfield                http://twitter.com/search?q=Anfield
# 47             ONE OF US        http://twitter.com/search?q=%22ONE+OF+US%22
# 48            Matt Lucas       http://twitter.com/search?q=%22Matt+Lucas%22
#
#    promoted_content                     query  tweet_volume
# 0              None      %23HarshRealityNosis           NaN
# 1              None                    Wilbur       10813.0
# 2              None                Merseyside       35694.0
# 3              None        %22Martin+Tyler%22           NaN
# 4              None                      Reds       40585.0
# 5              None       %22Paul+Mitchell%22           NaN
# 6              None                   Souness           NaN
# 7              None                   Giannis       27470.0
# 8              None      %22Andy+Robertson%22           NaN
# 9              None                     Allan       19500.0
# 10             None                  Goodison           NaN
# 11             None                  Panthers       14417.0
# 12             None      %22Basic+Instinct%22       12984.0
# 13             None                    Macron     1303360.0
# 14             None              %22Le+Pen%22      567706.0
# 15             None                   Everton      208831.0
# 16             None                     Jokic       30603.0
# 17             None                  %23Grace           NaN
# 18             None           %23forgotten80s           NaN
# 19             None                    Ranboo       81373.0
# 20             None        %23SASWhoDaresWins           NaN
# 21             None          %22The+French%22      142019.0
# 22             None                    Gordon       50695.0
# 23             None    %23FrenchElections2022       16212.0
# 24             None                   Wiggins       15308.0
# 25             None                      Klay       31448.0
# 26             None                     Steph       71468.0
# 27             None                     Origi       71980.0
# 28             None      %22Vive+la+France%22       39247.0
# 29             None               Richarlison       30988.0
# 30             None                    Denver       27862.0
# 31             None                  Pickford       24818.0
# 32             None                     Milan       81035.0
# 33             None                  Warriors      179169.0
# 34             None     %22Brennan+Johnson%22           NaN
# 35             None                  Slovenia       35517.0
# 36             None                     Matip           NaN
# 37             None                 Melenchon      126586.0
# 38             None                    Frexit           NaN
# 39             None                    Rigged       25724.0
# 40             None     %2242%25+of+French%22           NaN
# 41             None                    Hyland           NaN
# 42             None                  Draymond       15342.0
# 43             None  %22team+of+the+season%22       11854.0
# 44             None                    Tonali       17572.0
# 45             None                      Diaz      118930.0
# 46             None                   Anfield       31206.0
# 47             None           %22ONE+OF+US%22      108785.0
# 48             None          %22Matt+Lucas%22           NaN

# %%
# narrow list down to 50 000 tweets
our_city_trends_2_over50k_pd = our_city_trends_2_pd[our_city_trends_2_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# view the output
print(our_city_trends_2_over50k_pd.shape)
our_city_trends_2_over50k_pd
# Out:
# (13, 5)
#           name                                           url promoted_content  \
# 13      Macron            http://twitter.com/search?q=Macron             None
# 14      Le Pen      http://twitter.com/search?q=%22Le+Pen%22             None
# 15     Everton           http://twitter.com/search?q=Everton             None
# 33    Warriors          http://twitter.com/search?q=Warriors             None
# 21  The French  http://twitter.com/search?q=%22The+French%22             None
# 37   Melenchon         http://twitter.com/search?q=Melenchon             None
# 45        Diaz              http://twitter.com/search?q=Diaz             None
# 47   ONE OF US   http://twitter.com/search?q=%22ONE+OF+US%22             None
# 19      Ranboo            http://twitter.com/search?q=Ranboo             None
# 32       Milan             http://twitter.com/search?q=Milan             None
# 27       Origi             http://twitter.com/search?q=Origi             None
# 26       Steph             http://twitter.com/search?q=Steph             None
# 22      Gordon            http://twitter.com/search?q=Gordon             None
#
#                query  tweet_volume
# 13            Macron     1303360.0
# 14      %22Le+Pen%22      567706.0
# 15           Everton      208831.0
# 33          Warriors      179169.0
# 21  %22The+French%22      142019.0
# 37         Melenchon      126586.0
# 45              Diaz      118930.0
# 47   %22ONE+OF+US%22      108785.0
# 19            Ranboo       81373.0
# 32             Milan       81035.0
# 27             Origi       71980.0
# 26             Steph       71468.0
# 22            Gordon       50695.0

# %%
# save output as CSV file
our_city_trends_2_over50k_pd.to_csv('_London_our_city_trends_2_over50k.csv', index=False)

# %% [markdown]
# ### Compare cities

# %%
# find New York
our_city = 'New York'

# create variable
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# view output
list_of_names_our_city[0]['woeid']
# Out:
# 2459115

# %%
# find London
our_city_2 = 'London'

# create variable
list_of_names_our_city_2 = [_ for _ in trends_worldwide if _['name'] == our_city_2]

# view output
list_of_names_our_city_2[0]['woeid']
# Out:
# 44418

# %%
# search for each city
# import json
import json

# search for New York
new_york_trends = twitter_api.trends.place(_id = 2459115)

# view JSON output
print(json.dumps(new_york_trends, indent = 4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Tylor Megill",
#                 "url": "http://twitter.com/search?q=%22Tylor+Megill%22",
#                 "promoted_content": null,
#                 "query": "%22Tylor+Megill%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#Barry",
#                 "url": "http://twitter.com/search?q=%23Barry",
#                 "promoted_content": null,
#                 "query": "%23Barry",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#RBNY",
#                 "url": "http://twitter.com/search?q=%23RBNY",
#                 "promoted_content": null,
#                 "query": "%23RBNY",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#FrenchElections2022",
#                 "url": "http://twitter.com/search?q=%23FrenchElections2022",
#                 "promoted_content": null,
#                 "query": "%23FrenchElections2022",
#                 "tweet_volume": 16248
#             },
#             {
#                 "name": "Vive la France",
#                 "url": "http://twitter.com/search?q=%22Vive+la+France%22",
#                 "promoted_content": null,
#                 "query": "%22Vive+la+France%22",
#                 "tweet_volume": 39363
#             },
#             {
#                 "name": "#RepBX",
#                 "url": "http://twitter.com/search?q=%23RepBX",
#                 "promoted_content": null,
#                 "query": "%23RepBX",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Tory",
#                 "url": "http://twitter.com/search?q=Tory",
#                 "promoted_content": null,
#                 "query": "Tory",
#                 "tweet_volume": 102012
#             },
#             {
#                 "name": "Staten Island",
#                 "url": "http://twitter.com/search?q=%22Staten+Island%22",
#                 "promoted_content": null,
#                 "query": "%22Staten+Island%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#WithYou",
#                 "url": "http://twitter.com/search?q=%23WithYou",
#                 "promoted_content": null,
#                 "query": "%23WithYou",
#                 "tweet_volume": 1541525
#             },
#             {
#                 "name": "Everton",
#                 "url": "http://twitter.com/search?q=Everton",
#                 "promoted_content": null,
#                 "query": "Everton",
#                 "tweet_volume": 208949
#             },
#             {
#                 "name": "Guardians",
#                 "url": "http://twitter.com/search?q=Guardians",
#                 "promoted_content": null,
#                 "query": "Guardians",
#                 "tweet_volume": 15121
#             },
#             {
#                 "name": "Jokic",
#                 "url": "http://twitter.com/search?q=Jokic",
#                 "promoted_content": null,
#                 "query": "Jokic",
#                 "tweet_volume": 30806
#             },
#             {
#                 "name": "Ben Simmons",
#                 "url": "http://twitter.com/search?q=%22Ben+Simmons%22",
#                 "promoted_content": null,
#                 "query": "%22Ben+Simmons%22",
#                 "tweet_volume": 83124
#             },
#             {
#                 "name": "Steph",
#                 "url": "http://twitter.com/search?q=Steph",
#                 "promoted_content": null,
#                 "query": "Steph",
#                 "tweet_volume": 71197
#             },
#             {
#                 "name": "Wiggins",
#                 "url": "http://twitter.com/search?q=Wiggins",
#                 "promoted_content": null,
#                 "query": "Wiggins",
#                 "tweet_volume": 14957
#             },
#             {
#                 "name": "Klay",
#                 "url": "http://twitter.com/search?q=Klay",
#                 "promoted_content": null,
#                 "query": "Klay",
#                 "tweet_volume": 31629
#             },
#             {
#                 "name": "Barton",
#                 "url": "http://twitter.com/search?q=Barton",
#                 "promoted_content": null,
#                 "query": "Barton",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Macron",
#                 "url": "http://twitter.com/search?q=Macron",
#                 "promoted_content": null,
#                 "query": "Macron",
#                 "tweet_volume": 1305975
#             },
#             {
#                 "name": "Nuggets",
#                 "url": "http://twitter.com/search?q=Nuggets",
#                 "promoted_content": null,
#                 "query": "Nuggets",
#                 "tweet_volume": 45235
#             },
#             {
#                 "name": "Steve Kerr",
#                 "url": "http://twitter.com/search?q=%22Steve+Kerr%22",
#                 "promoted_content": null,
#                 "query": "%22Steve+Kerr%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Draymond",
#                 "url": "http://twitter.com/search?q=Draymond",
#                 "promoted_content": null,
#                 "query": "Draymond",
#                 "tweet_volume": 15368
#             },
#             {
#                 "name": "Ranboo",
#                 "url": "http://twitter.com/search?q=Ranboo",
#                 "promoted_content": null,
#                 "query": "Ranboo",
#                 "tweet_volume": 82191
#             },
#             {
#                 "name": "Buxton",
#                 "url": "http://twitter.com/search?q=Buxton",
#                 "promoted_content": null,
#                 "query": "Buxton",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Denver",
#                 "url": "http://twitter.com/search?q=Denver",
#                 "promoted_content": null,
#                 "query": "Denver",
#                 "tweet_volume": 27956
#             },
#             {
#                 "name": "Le Pen",
#                 "url": "http://twitter.com/search?q=%22Le+Pen%22",
#                 "promoted_content": null,
#                 "query": "%22Le+Pen%22",
#                 "tweet_volume": 569262
#             },
#             {
#                 "name": "IPAs",
#                 "url": "http://twitter.com/search?q=IPAs",
#                 "promoted_content": null,
#                 "query": "IPAs",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ross Chastain",
#                 "url": "http://twitter.com/search?q=%22Ross+Chastain%22",
#                 "promoted_content": null,
#                 "query": "%22Ross+Chastain%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Otto Porter",
#                 "url": "http://twitter.com/search?q=%22Otto+Porter%22",
#                 "promoted_content": null,
#                 "query": "%22Otto+Porter%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Bones Hyland",
#                 "url": "http://twitter.com/search?q=%22Bones+Hyland%22",
#                 "promoted_content": null,
#                 "query": "%22Bones+Hyland%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Larson",
#                 "url": "http://twitter.com/search?q=Larson",
#                 "promoted_content": null,
#                 "query": "Larson",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Austin Rivers",
#                 "url": "http://twitter.com/search?q=%22Austin+Rivers%22",
#                 "promoted_content": null,
#                 "query": "%22Austin+Rivers%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Newt",
#                 "url": "http://twitter.com/search?q=Newt",
#                 "promoted_content": null,
#                 "query": "Newt",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Publix",
#                 "url": "http://twitter.com/search?q=Publix",
#                 "promoted_content": null,
#                 "query": "Publix",
#                 "tweet_volume": 22429
#             },
#             {
#                 "name": "Pe\u00f1a",
#                 "url": "http://twitter.com/search?q=Pe%C3%B1a",
#                 "promoted_content": null,
#                 "query": "Pe%C3%B1a",
#                 "tweet_volume": 150331
#             },
#             {
#                 "name": "Bubba",
#                 "url": "http://twitter.com/search?q=Bubba",
#                 "promoted_content": null,
#                 "query": "Bubba",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Travis Hunter",
#                 "url": "http://twitter.com/search?q=%22Travis+Hunter%22",
#                 "promoted_content": null,
#                 "query": "%22Travis+Hunter%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Monte Morris",
#                 "url": "http://twitter.com/search?q=%22Monte+Morris%22",
#                 "promoted_content": null,
#                 "query": "%22Monte+Morris%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Bellinger",
#                 "url": "http://twitter.com/search?q=Bellinger",
#                 "promoted_content": null,
#                 "query": "Bellinger",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Boogie",
#                 "url": "http://twitter.com/search?q=Boogie",
#                 "promoted_content": null,
#                 "query": "Boogie",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Grayson Allen",
#                 "url": "http://twitter.com/search?q=%22Grayson+Allen%22",
#                 "promoted_content": null,
#                 "query": "%22Grayson+Allen%22",
#                 "tweet_volume": 14324
#             },
#             {
#                 "name": "Aaron Gordon",
#                 "url": "http://twitter.com/search?q=%22Aaron+Gordon%22",
#                 "promoted_content": null,
#                 "query": "%22Aaron+Gordon%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Bednar",
#                 "url": "http://twitter.com/search?q=Bednar",
#                 "promoted_content": null,
#                 "query": "Bednar",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Erik Jones",
#                 "url": "http://twitter.com/search?q=%22Erik+Jones%22",
#                 "promoted_content": null,
#                 "query": "%22Erik+Jones%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Xavi",
#                 "url": "http://twitter.com/search?q=Xavi",
#                 "promoted_content": null,
#                 "query": "Xavi",
#                 "tweet_volume": 65491
#             },
#             {
#                 "name": "Game 5",
#                 "url": "http://twitter.com/search?q=%22Game+5%22",
#                 "promoted_content": null,
#                 "query": "%22Game+5%22",
#                 "tweet_volume": 56134
#             },
#             {
#                 "name": "Noah Cates",
#                 "url": "http://twitter.com/search?q=%22Noah+Cates%22",
#                 "promoted_content": null,
#                 "query": "%22Noah+Cates%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Massless",
#                 "url": "http://twitter.com/search?q=Massless",
#                 "promoted_content": null,
#                 "query": "Massless",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Doris Burke",
#                 "url": "http://twitter.com/search?q=%22Doris+Burke%22",
#                 "promoted_content": null,
#                 "query": "%22Doris+Burke%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Giannis",
#                 "url": "http://twitter.com/search?q=Giannis",
#                 "promoted_content": null,
#                 "query": "Giannis",
#                 "tweet_volume": 27529
#             },
#             {
#                 "name": "Kuminga",
#                 "url": "http://twitter.com/search?q=Kuminga",
#                 "promoted_content": null,
#                 "query": "Kuminga",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-04-24T23:18:59Z",
#         "created_at": "2022-04-20T05:45:31Z",
#         "locations": [
#             {
#                 "name": "New York",
#                 "woeid": 2459115
#             }
#         ]
#     }
# ]

# %%
# search for each city
# import json
import json

# search for London
london_trends = twitter_api.trends.place(_id = 44418)

# view JSON output
print(json.dumps(london_trends, indent = 4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "#HarshRealityNosis",
#                 "url": "http://twitter.com/search?q=%23HarshRealityNosis",
#                 "promoted_content": null,
#                 "query": "%23HarshRealityNosis",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#NKOTBDay",
#                 "url": "http://twitter.com/search?q=%23NKOTBDay",
#                 "promoted_content": null,
#                 "query": "%23NKOTBDay",
#                 "tweet_volume": 10493
#             },
#             {
#                 "name": "Wilbur",
#                 "url": "http://twitter.com/search?q=Wilbur",
#                 "promoted_content": null,
#                 "query": "Wilbur",
#                 "tweet_volume": 10821
#             },
#             {
#                 "name": "Merseyside",
#                 "url": "http://twitter.com/search?q=Merseyside",
#                 "promoted_content": null,
#                 "query": "Merseyside",
#                 "tweet_volume": 35712
#             },
#             {
#                 "name": "Martin Tyler",
#                 "url": "http://twitter.com/search?q=%22Martin+Tyler%22",
#                 "promoted_content": null,
#                 "query": "%22Martin+Tyler%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Reds",
#                 "url": "http://twitter.com/search?q=Reds",
#                 "promoted_content": null,
#                 "query": "Reds",
#                 "tweet_volume": 40636
#             },
#             {
#                 "name": "Paul Mitchell",
#                 "url": "http://twitter.com/search?q=%22Paul+Mitchell%22",
#                 "promoted_content": null,
#                 "query": "%22Paul+Mitchell%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Souness",
#                 "url": "http://twitter.com/search?q=Souness",
#                 "promoted_content": null,
#                 "query": "Souness",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Giannis",
#                 "url": "http://twitter.com/search?q=Giannis",
#                 "promoted_content": null,
#                 "query": "Giannis",
#                 "tweet_volume": 27529
#             },
#             {
#                 "name": "Andy Robertson",
#                 "url": "http://twitter.com/search?q=%22Andy+Robertson%22",
#                 "promoted_content": null,
#                 "query": "%22Andy+Robertson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Allan",
#                 "url": "http://twitter.com/search?q=Allan",
#                 "promoted_content": null,
#                 "query": "Allan",
#                 "tweet_volume": 19548
#             },
#             {
#                 "name": "Goodison",
#                 "url": "http://twitter.com/search?q=Goodison",
#                 "promoted_content": null,
#                 "query": "Goodison",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Basic Instinct",
#                 "url": "http://twitter.com/search?q=%22Basic+Instinct%22",
#                 "promoted_content": null,
#                 "query": "%22Basic+Instinct%22",
#                 "tweet_volume": 12992
#             },
#             {
#                 "name": "Macron",
#                 "url": "http://twitter.com/search?q=Macron",
#                 "promoted_content": null,
#                 "query": "Macron",
#                 "tweet_volume": 1306824
#             },
#             {
#                 "name": "Le Pen",
#                 "url": "http://twitter.com/search?q=%22Le+Pen%22",
#                 "promoted_content": null,
#                 "query": "%22Le+Pen%22",
#                 "tweet_volume": 569262
#             },
#             {
#                 "name": "Everton",
#                 "url": "http://twitter.com/search?q=Everton",
#                 "promoted_content": null,
#                 "query": "Everton",
#                 "tweet_volume": 208898
#             },
#             {
#                 "name": "Jokic",
#                 "url": "http://twitter.com/search?q=Jokic",
#                 "promoted_content": null,
#                 "query": "Jokic",
#                 "tweet_volume": 30864
#             },
#             {
#                 "name": "#Grace",
#                 "url": "http://twitter.com/search?q=%23Grace",
#                 "promoted_content": null,
#                 "query": "%23Grace",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#forgotten80s",
#                 "url": "http://twitter.com/search?q=%23forgotten80s",
#                 "promoted_content": null,
#                 "query": "%23forgotten80s",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ranboo",
#                 "url": "http://twitter.com/search?q=Ranboo",
#                 "promoted_content": null,
#                 "query": "Ranboo",
#                 "tweet_volume": 82191
#             },
#             {
#                 "name": "#SASWhoDaresWins",
#                 "url": "http://twitter.com/search?q=%23SASWhoDaresWins",
#                 "promoted_content": null,
#                 "query": "%23SASWhoDaresWins",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "The French",
#                 "url": "http://twitter.com/search?q=%22The+French%22",
#                 "promoted_content": null,
#                 "query": "%22The+French%22",
#                 "tweet_volume": 142596
#             },
#             {
#                 "name": "Gordon",
#                 "url": "http://twitter.com/search?q=Gordon",
#                 "promoted_content": null,
#                 "query": "Gordon",
#                 "tweet_volume": 50797
#             },
#             {
#                 "name": "Wiggins",
#                 "url": "http://twitter.com/search?q=Wiggins",
#                 "promoted_content": null,
#                 "query": "Wiggins",
#                 "tweet_volume": 14957
#             },
#             {
#                 "name": "Klay",
#                 "url": "http://twitter.com/search?q=Klay",
#                 "promoted_content": null,
#                 "query": "Klay",
#                 "tweet_volume": 31681
#             },
#             {
#                 "name": "Steph",
#                 "url": "http://twitter.com/search?q=Steph",
#                 "promoted_content": null,
#                 "query": "Steph",
#                 "tweet_volume": 71197
#             },
#             {
#                 "name": "Origi",
#                 "url": "http://twitter.com/search?q=Origi",
#                 "promoted_content": null,
#                 "query": "Origi",
#                 "tweet_volume": 72038
#             },
#             {
#                 "name": "Vive la France",
#                 "url": "http://twitter.com/search?q=%22Vive+la+France%22",
#                 "promoted_content": null,
#                 "query": "%22Vive+la+France%22",
#                 "tweet_volume": 39335
#             },
#             {
#                 "name": "Richarlison",
#                 "url": "http://twitter.com/search?q=Richarlison",
#                 "promoted_content": null,
#                 "query": "Richarlison",
#                 "tweet_volume": 31006
#             },
#             {
#                 "name": "Denver",
#                 "url": "http://twitter.com/search?q=Denver",
#                 "promoted_content": null,
#                 "query": "Denver",
#                 "tweet_volume": 27956
#             },
#             {
#                 "name": "Pickford",
#                 "url": "http://twitter.com/search?q=Pickford",
#                 "promoted_content": null,
#                 "query": "Pickford",
#                 "tweet_volume": 24861
#             },
#             {
#                 "name": "Milan",
#                 "url": "http://twitter.com/search?q=Milan",
#                 "promoted_content": null,
#                 "query": "Milan",
#                 "tweet_volume": 81213
#             },
#             {
#                 "name": "Warriors",
#                 "url": "http://twitter.com/search?q=Warriors",
#                 "promoted_content": null,
#                 "query": "Warriors",
#                 "tweet_volume": 179938
#             },
#             {
#                 "name": "Brennan Johnson",
#                 "url": "http://twitter.com/search?q=%22Brennan+Johnson%22",
#                 "promoted_content": null,
#                 "query": "%22Brennan+Johnson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Slovenia",
#                 "url": "http://twitter.com/search?q=Slovenia",
#                 "promoted_content": null,
#                 "query": "Slovenia",
#                 "tweet_volume": 35788
#             },
#             {
#                 "name": "Matip",
#                 "url": "http://twitter.com/search?q=Matip",
#                 "promoted_content": null,
#                 "query": "Matip",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Melenchon",
#                 "url": "http://twitter.com/search?q=Melenchon",
#                 "promoted_content": null,
#                 "query": "Melenchon",
#                 "tweet_volume": 126861
#             },
#             {
#                 "name": "Rigged",
#                 "url": "http://twitter.com/search?q=Rigged",
#                 "promoted_content": null,
#                 "query": "Rigged",
#                 "tweet_volume": 25903
#             },
#             {
#                 "name": "Frexit",
#                 "url": "http://twitter.com/search?q=Frexit",
#                 "promoted_content": null,
#                 "query": "Frexit",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "42% of French",
#                 "url": "http://twitter.com/search?q=%2242%25+of+French%22",
#                 "promoted_content": null,
#                 "query": "%2242%25+of+French%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Hyland",
#                 "url": "http://twitter.com/search?q=Hyland",
#                 "promoted_content": null,
#                 "query": "Hyland",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Draymond",
#                 "url": "http://twitter.com/search?q=Draymond",
#                 "promoted_content": null,
#                 "query": "Draymond",
#                 "tweet_volume": 15373
#             },
#             {
#                 "name": "team of the season",
#                 "url": "http://twitter.com/search?q=%22team+of+the+season%22",
#                 "promoted_content": null,
#                 "query": "%22team+of+the+season%22",
#                 "tweet_volume": 11894
#             },
#             {
#                 "name": "Tonali",
#                 "url": "http://twitter.com/search?q=Tonali",
#                 "promoted_content": null,
#                 "query": "Tonali",
#                 "tweet_volume": 17628
#             },
#             {
#                 "name": "Diaz",
#                 "url": "http://twitter.com/search?q=Diaz",
#                 "promoted_content": null,
#                 "query": "Diaz",
#                 "tweet_volume": 119158
#             },
#             {
#                 "name": "Anfield",
#                 "url": "http://twitter.com/search?q=Anfield",
#                 "promoted_content": null,
#                 "query": "Anfield",
#                 "tweet_volume": 31241
#             },
#             {
#                 "name": "ONE OF US",
#                 "url": "http://twitter.com/search?q=%22ONE+OF+US%22",
#                 "promoted_content": null,
#                 "query": "%22ONE+OF+US%22",
#                 "tweet_volume": 109043
#             },
#             {
#                 "name": "Matt Lucas",
#                 "url": "http://twitter.com/search?q=%22Matt+Lucas%22",
#                 "promoted_content": null,
#                 "query": "%22Matt+Lucas%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Far Right",
#                 "url": "http://twitter.com/search?q=%22Far+Right%22",
#                 "promoted_content": null,
#                 "query": "%22Far+Right%22",
#                 "tweet_volume": 61914
#             }
#         ],
#         "as_of": "2022-04-24T23:19:20Z",
#         "created_at": "2022-04-20T05:45:31Z",
#         "locations": [
#             {
#                 "name": "London",
#                 "woeid": 44418
#             }
#         ]
#     }
# ]

# %%
# find common topics
new_york_trends_list = [trend['name'] for trend in new_york_trends[0]['trends']]

# view output
print(new_york_trends_list)
# Out:
# ['Tylor Megill', '#Barry', '#RBNY', '#FrenchElections2022', 'Vive la France', '#RepBX', 'Tory', 'Staten Island', '#WithYou', 'Everton', 'Guardians', 'Jokic', 'Ben Simmons', 'Steph', 'Wiggins', 'Klay', 'Barton', 'Macron', 'Nuggets', 'Steve Kerr', 'Draymond', 'Ranboo', 'Buxton', 'Denver', 'Le Pen', 'IPAs', 'Ross Chastain', 'Otto Porter', 'Bones Hyland', 'Larson', 'Austin Rivers', 'Newt', 'Publix', 'Peña', 'Bubba', 'Travis Hunter', 'Monte Morris', 'Bellinger', 'Boogie', 'Grayson Allen', 'Aaron Gordon', 'Bednar', 'Erik Jones', 'Xavi', 'Game 5', 'Noah Cates', 'Massless', 'Doris Burke', 'Giannis', 'Kuminga']

# %%
# find common topics
london_trends_list = [trend['name'] for trend in london_trends[0]['trends']]

# view output
print(london_trends_list)
# Out:
# ['#HarshRealityNosis', '#NKOTBDay', 'Wilbur', 'Merseyside', 'Martin Tyler', 'Reds', 'Paul Mitchell', 'Souness', 'Giannis', 'Andy Robertson', 'Allan', 'Goodison', 'Basic Instinct', 'Macron', 'Le Pen', 'Everton', 'Jokic', '#Grace', '#forgotten80s', 'Ranboo', '#SASWhoDaresWins', 'The French', 'Gordon', 'Wiggins', 'Klay', 'Steph', 'Origi', 'Vive la France', 'Richarlison', 'Denver', 'Pickford', 'Milan', 'Warriors', 'Brennan Johnson', 'Slovenia', 'Matip', 'Melenchon', 'Rigged', 'Frexit', '42% of French', 'Hyland', 'Draymond', 'team of the season', 'Tonali', 'Diaz', 'Anfield', 'ONE OF US', 'Matt Lucas', 'Far Right']

# %%
# find trends between cities
new_york_trends_set = set(new_york_trends_list)
london_trends_set = set(london_trends_list)

# set variable
common_trends = new_york_trends_set.intersection(london_trends_set)

# view output
print(common_trends)
# Out:
# {'Everton', 'Ranboo', 'Draymond', 'Wiggins', 'Denver', 'Jokic', 'Klay', 'Macron', 'Le Pen', 'Giannis', 'Steph', 'Vive la France'}

# %% [markdown]
# ### Search for #Bitcoin

# %%
# run a test with #Bitcoin
bitcoin_tweets = twitter_api.search.tweets(q = '#Bitcoin')

# view JSON output
print(json.dumps(bitcoin_tweets, indent = 4))
# Out:
# {
#     "statuses": [
#         {
#             "created_at": "Sun Apr 24 23:22:15 +0000 2022",
#             "id": 1518369760861425664,
#             "id_str": "1518369760861425664",
#             "text": "RT @saylor: The future of money is already here, it\u2019s just not evenly distributed. #Bitcoin https://t.co/Da2evgBgDJ",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             83,
#                             91
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "saylor",
#                         "name": "Michael Saylor\u26a1\ufe0f",
#                         "id": 244647486,
#                         "id_str": "244647486",
#                         "indices": [
#                             3,
#                             10
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1517211868158431233,
#                         "id_str": "1517211868158431233",
#                         "indices": [
#                             92,
#                             115
#                         ],
#                         "media_url": "http://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                         "media_url_https": "https://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                         "url": "https://t.co/Da2evgBgDJ",
#                         "display_url": "pic.twitter.com/Da2evgBgDJ",
#                         "expanded_url": "https://twitter.com/crypto/status/1518234052532183041/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 1920,
#                                 "h": 1080,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1518234052532183041,
#                         "source_status_id_str": "1518234052532183041",
#                         "source_user_id": 928759224599040001,
#                         "source_user_id_str": "928759224599040001"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1517211868158431233,
#                         "id_str": "1517211868158431233",
#                         "indices": [
#                             92,
#                             115
#                         ],
#                         "media_url": "http://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                         "media_url_https": "https://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                         "url": "https://t.co/Da2evgBgDJ",
#                         "display_url": "pic.twitter.com/Da2evgBgDJ",
#                         "expanded_url": "https://twitter.com/crypto/status/1518234052532183041/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 1920,
#                                 "h": 1080,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1518234052532183041,
#                         "source_status_id_str": "1518234052532183041",
#                         "source_user_id": 928759224599040001,
#                         "source_user_id_str": "928759224599040001",
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "duration_millis": 145257,
#                             "variants": [
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/amplify_video/1517211868158431233/vid/640x360/DuHB-k3xoKC3ddda.mp4?tag=14"
#                                 },
#                                 {
#                                     "bitrate": 288000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/amplify_video/1517211868158431233/vid/480x270/n2zanU7VrgB4pH1g.mp4?tag=14"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/amplify_video/1517211868158431233/pl/eLGNXlJ_okFsw8w-.m3u8?tag=14&container=fmp4"
#                                 },
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/amplify_video/1517211868158431233/vid/1280x720/qj0Tjm32YQhoCyHs.mp4?tag=14"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "title": "What Does the War in Ukraine Mean for Crypto?",
#                             "description": "Crypto fans sometimes talk about war and societal collapse as positive for their cause. It goes deeper than you might think. Bloomberg\u2019s Eddie van der Walt breaks down the mixed signals.",
#                             "embeddable": true,
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1034332325730050048,
#                 "id_str": "1034332325730050048",
#                 "name": "Frek",
#                 "screen_name": "Frek58136182",
#                 "location": "la coru\u00f1a 2",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 213,
#                 "friends_count": 1115,
#                 "listed_count": 59,
#                 "created_at": "Tue Aug 28 06:50:18 +0000 2018",
#                 "favourites_count": 19054,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 21238,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1034341725781811200/58be4t48_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1034341725781811200/58be4t48_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Sun Apr 24 16:45:31 +0000 2022",
#                 "id": 1518269920873787393,
#                 "id_str": "1518269920873787393",
#                 "text": "The future of money is already here, it\u2019s just not evenly distributed. #Bitcoin https://t.co/Da2evgBgDJ",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 71,
#                                 79
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1517211868158431233,
#                             "id_str": "1517211868158431233",
#                             "indices": [
#                                 80,
#                                 103
#                             ],
#                             "media_url": "http://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                             "media_url_https": "https://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                             "url": "https://t.co/Da2evgBgDJ",
#                             "display_url": "pic.twitter.com/Da2evgBgDJ",
#                             "expanded_url": "https://twitter.com/crypto/status/1518234052532183041/video/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "large": {
#                                     "w": 1920,
#                                     "h": 1080,
#                                     "resize": "fit"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 675,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 383,
#                                     "resize": "fit"
#                                 }
#                             },
#                             "source_status_id": 1518234052532183041,
#                             "source_status_id_str": "1518234052532183041",
#                             "source_user_id": 928759224599040001,
#                             "source_user_id_str": "928759224599040001"
#                         }
#                     ]
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "id": 1517211868158431233,
#                             "id_str": "1517211868158431233",
#                             "indices": [
#                                 80,
#                                 103
#                             ],
#                             "media_url": "http://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                             "media_url_https": "https://pbs.twimg.com/amplify_video_thumb/1517211868158431233/img/qzbd65Nc5hC4_RXR.jpg",
#                             "url": "https://t.co/Da2evgBgDJ",
#                             "display_url": "pic.twitter.com/Da2evgBgDJ",
#                             "expanded_url": "https://twitter.com/crypto/status/1518234052532183041/video/1",
#                             "type": "video",
#                             "sizes": {
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "large": {
#                                     "w": 1920,
#                                     "h": 1080,
#                                     "resize": "fit"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 675,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 383,
#                                     "resize": "fit"
#                                 }
#                             },
#                             "source_status_id": 1518234052532183041,
#                             "source_status_id_str": "1518234052532183041",
#                             "source_user_id": 928759224599040001,
#                             "source_user_id_str": "928759224599040001",
#                             "video_info": {
#                                 "aspect_ratio": [
#                                     16,
#                                     9
#                                 ],
#                                 "duration_millis": 145257,
#                                 "variants": [
#                                     {
#                                         "bitrate": 832000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/amplify_video/1517211868158431233/vid/640x360/DuHB-k3xoKC3ddda.mp4?tag=14"
#                                     },
#                                     {
#                                         "bitrate": 288000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/amplify_video/1517211868158431233/vid/480x270/n2zanU7VrgB4pH1g.mp4?tag=14"
#                                     },
#                                     {
#                                         "content_type": "application/x-mpegURL",
#                                         "url": "https://video.twimg.com/amplify_video/1517211868158431233/pl/eLGNXlJ_okFsw8w-.m3u8?tag=14&container=fmp4"
#                                     },
#                                     {
#                                         "bitrate": 2176000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/amplify_video/1517211868158431233/vid/1280x720/qj0Tjm32YQhoCyHs.mp4?tag=14"
#                                     }
#                                 ]
#                             },
#                             "additional_media_info": {
#                                 "title": "What Does the War in Ukraine Mean for Crypto?",
#                                 "description": "Crypto fans sometimes talk about war and societal collapse as positive for their cause. It goes deeper than you might think. Bloomberg\u2019s Eddie van der Walt breaks down the mixed signals.",
#                                 "embeddable": true,
#                                 "monetizable": false
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 244647486,
#                     "id_str": "244647486",
#                     "name": "Michael Saylor\u26a1\ufe0f",
#                     "screen_name": "saylor",
#                     "location": "Miami Beach, FL",
#                     "description": "$MSTR Founder & CEO | @MIT Aerospace | bio @ https://t.co/9Zlq0oHqyh | free education @ https://t.co/4L1s0iwzQ6 | #Bitcoin is https://t.co/ejezpjeUZ4 & https://t.co/SLbKcP1BnV. | All tweets are my own.",
#                     "url": "https://t.co/OgF8IgNiDo",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/OgF8IgNiDo",
#                                     "expanded_url": "https://microstrategy.com",
#                                     "display_url": "microstrategy.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/9Zlq0oHqyh",
#                                     "expanded_url": "http://michael.com",
#                                     "display_url": "michael.com",
#                                     "indices": [
#                                         45,
#                                         68
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/4L1s0iwzQ6",
#                                     "expanded_url": "http://saylor.org",
#                                     "display_url": "saylor.org",
#                                     "indices": [
#                                         88,
#                                         111
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/ejezpjeUZ4",
#                                     "expanded_url": "http://hope.com",
#                                     "display_url": "hope.com",
#                                     "indices": [
#                                         126,
#                                         149
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/SLbKcP1BnV",
#                                     "expanded_url": "http://strategy.com",
#                                     "display_url": "strategy.com",
#                                     "indices": [
#                                         152,
#                                         175
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2369412,
#                     "friends_count": 582,
#                     "listed_count": 13967,
#                     "created_at": "Sat Jan 29 20:11:04 +0000 2011",
#                     "favourites_count": 2509,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": true,
#                     "statuses_count": 3241,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "C0DEED",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1485632175932383235/8t0DGo6V_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1485632175932383235/8t0DGo6V_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/244647486/1606261344",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": false,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 433,
#                 "favorite_count": 2569,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 433,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sun Apr 24 23:22:14 +0000 2022",
#             "id": 1518369758374416384,
#             "id_str": "1518369758374416384",
#             "text": "RT @ohhwesley89: #VeChain $VET \ud83d\ude80\n\nYesterday \nVeChainThor Accounts: 1,765,322\n\nToday\nVeChainThor Accounts: 1,766,135\n\nClauses: 81,892\nMkt Ca\u2026",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "VeChain",
#                         "indices": [
#                             17,
#                             25
#                         ]
#                     }
#                 ],
#                 "symbols": [
#                     {
#                         "text": "VET",
#                         "indices": [
#                             26,
#                             30
#                         ]
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "screen_name": "ohhwesley89",
#                         "name": "ohhwesley \u24cb \ud83c\uddfa\ud83c\udde6",
#                         "id": 928159477525725186,
#                         "id_str": "928159477525725186",
#                         "indices": [
#                             3,
#                             15
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1460882775423160326,
#                 "id_str": "1460882775423160326",
#                 "name": "JCYK",
#                 "screen_name": "MAFIABOSS_XRP",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 71,
#                 "friends_count": 173,
#                 "listed_count": 2,
#                 "created_at": "Wed Nov 17 08:09:49 +0000 2021",
#                 "favourites_count": 9471,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 4263,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1460884463441756161/kboE12jU_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1460884463441756161/kboE12jU_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Sun Apr 24 22:02:53 +0000 2022",
#                 "id": 1518349786897821696,
#                 "id_str": "1518349786897821696",
#                 "text": "#VeChain $VET \ud83d\ude80\n\nYesterday \nVeChainThor Accounts: 1,765,322\n\nToday\nVeChainThor Accounts: 1,766,135\n\nClauses: 81,892\u2026 https://t.co/LqY1LE4wXz",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "VeChain",
#                             "indices": [
#                                 0,
#                                 8
#                             ]
#                         }
#                     ],
#                     "symbols": [
#                         {
#                             "text": "VET",
#                             "indices": [
#                                 9,
#                                 13
#                             ]
#                         }
#                     ],
#                     "user_mentions": [],
#                     "urls": [
#                         {
#                             "url": "https://t.co/LqY1LE4wXz",
#                             "expanded_url": "https://twitter.com/i/web/status/1518349786897821696",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 117,
#                                 140
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 928159477525725186,
#                     "id_str": "928159477525725186",
#                     "name": "ohhwesley \u24cb \ud83c\uddfa\ud83c\udde6",
#                     "screen_name": "ohhwesley89",
#                     "location": "VeFam",
#                     "description": "HODLING: $VET 30%, $BTC 30%, $ETH 20%, $LINK 5%, $MATIC 5%, $LUNA 5%, $ATOM 5%, LEVERAGE 0%.\n\nBitcoin is for the people.  Fiat is for the elite.",
#                     "url": null,
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2212,
#                     "friends_count": 847,
#                     "listed_count": 18,
#                     "created_at": "Wed Nov 08 07:17:18 +0000 2017",
#                     "favourites_count": 21586,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 6498,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1500381793853214720/Hoo6gmDc_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1500381793853214720/Hoo6gmDc_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/928159477525725186/1635193918",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 5,
#                 "favorite_count": 23,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 5,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sun Apr 24 23:22:13 +0000 2022",
#             "id": 1518369754087854080,
#             "id_str": "1518369754087854080",
#             "text": "I am claiming my free Lightning sats from @_bitcoiner's zesty faucet! \u26a1\n\n@boltcoiner unlock me 62ebe310-04f2-4473-8\u2026 https://t.co/Qs57gAVdIV",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "_bitcoiner",
#                         "name": "bitcoiner",
#                         "id": 863624208705888257,
#                         "id_str": "863624208705888257",
#                         "indices": [
#                             42,
#                             53
#                         ]
#                     },
#                     {
#                         "screen_name": "boltcoiner",
#                         "name": "boltcoiner \u26a1",
#                         "id": 1463021259709566977,
#                         "id_str": "1463021259709566977",
#                         "indices": [
#                             73,
#                             84
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/Qs57gAVdIV",
#                         "expanded_url": "https://twitter.com/i/web/status/1518369754087854080",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1270253343760211968,
#                 "id_str": "1270253343760211968",
#                 "name": "seekkh",
#                 "screen_name": "seekkh2",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2,
#                 "friends_count": 15,
#                 "listed_count": 0,
#                 "created_at": "Tue Jun 09 07:16:17 +0000 2020",
#                 "favourites_count": 17,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 52,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": true,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sun Apr 24 23:22:13 +0000 2022",
#             "id": 1518369753777197063,
#             "id_str": "1518369753777197063",
#             "text": "RT @Dennis_Porter_: HUGE BREAKING NEWS - The Central African Republic has unanimously passed a bill to adopt #Bitcoin as legal tender.",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             109,
#                             117
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "Dennis_Porter_",
#                         "name": "Dennis Porter",
#                         "id": 1291243382128304133,
#                         "id_str": "1291243382128304133",
#                         "indices": [
#                             3,
#                             18
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1347963187669463047,
#                 "id_str": "1347963187669463047",
#                 "name": "Gary",
#                 "screen_name": "4VirginiaTech",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 54,
#                 "friends_count": 123,
#                 "listed_count": 3,
#                 "created_at": "Sat Jan 09 17:48:01 +0000 2021",
#                 "favourites_count": 16213,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 535,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1347963879100473348/gmZR9pvy_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1347963879100473348/gmZR9pvy_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Sun Apr 24 18:13:04 +0000 2022",
#                 "id": 1518291950188781571,
#                 "id_str": "1518291950188781571",
#                 "text": "HUGE BREAKING NEWS - The Central African Republic has unanimously passed a bill to adopt #Bitcoin as legal tender.",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 89,
#                                 97
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": []
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1291243382128304133,
#                     "id_str": "1291243382128304133",
#                     "name": "Dennis Porter",
#                     "screen_name": "Dennis_Porter_",
#                     "location": "Oregon, USA",
#                     "description": "Covering #Bitcoin+ Politics | Advancing BTC policy | Single Issue Voter | Host @RealDennisShow | @HODLpac Endorsement | @Compass_mining EP",
#                     "url": "https://t.co/04SAjDKfAz",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/04SAjDKfAz",
#                                     "expanded_url": "https://www.youtube.com/c/DennisPorter",
#                                     "display_url": "youtube.com/c/DennisPorter",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 92200,
#                     "friends_count": 1929,
#                     "listed_count": 645,
#                     "created_at": "Thu Aug 06 05:23:19 +0000 2020",
#                     "favourites_count": 11899,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 13445,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1459785836765925383/hHThGRg8_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1459785836765925383/hHThGRg8_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1291243382128304133/1635806183",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 2066,
#                 "favorite_count": 11067,
#                 "favorited": false,
#                 "retweeted": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 2066,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sun Apr 24 23:22:13 +0000 2022",
#             "id": 1518369750849572864,
#             "id_str": "1518369750849572864",
#             "text": "RT @Crypto__Goku: [#THREAD + #GIVEAWAY]\n\nLe projet @WineBottleClub vous offre 1 whitelist et une bouteille Bitcoin millesime 2017 \ud83c\udf77\n\n\ud83d\udc49Pour\u2026",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "THREAD",
#                         "indices": [
#                             19,
#                             26
#                         ]
#                     },
#                     {
#                         "text": "GIVEAWAY",
#                         "indices": [
#                             29,
#                             38
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "Crypto__Goku",
#                         "name": "Goku \ud83d\udd25",
#                         "id": 1395846093389316096,
# ...
#                         "id_str": "1518310679517835267",
#                         "indices": [
#                             58,
#                             81
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                         "url": "https://t.co/RlgYjbhxzs",
#                         "display_url": "pic.twitter.com/RlgYjbhxzs",
#                         "expanded_url": "https://twitter.com/thecryptoc0up1e/status/1518312181162459137/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1920,
#                                 "h": 1080,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1518312181162459137,
#                         "source_status_id_str": "1518312181162459137",
#                         "source_user_id": 1395095108421292035,
#                         "source_user_id_str": "1395095108421292035"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1518310679517835267,
#                         "id_str": "1518310679517835267",
#                         "indices": [
#                             58,
#                             81
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                         "url": "https://t.co/RlgYjbhxzs",
#                         "display_url": "pic.twitter.com/RlgYjbhxzs",
#                         "expanded_url": "https://twitter.com/thecryptoc0up1e/status/1518312181162459137/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1920,
#                                 "h": 1080,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1518312181162459137,
#                         "source_status_id_str": "1518312181162459137",
#                         "source_user_id": 1395095108421292035,
#                         "source_user_id_str": "1395095108421292035"
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1462547106158325761,
#                 "id_str": "1462547106158325761",
#                 "name": "inNameOfCrypto",
#                 "screen_name": "inNameOfCrypto",
#                 "location": "Planet Earth",
#                 "description": "Thinking in $Crypto everywhere & everyday",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 12,
#                 "friends_count": 249,
#                 "listed_count": 9,
#                 "created_at": "Sun Nov 21 22:23:08 +0000 2021",
#                 "favourites_count": 113,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 116,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1462547223691108361/JunDDve7_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1462547223691108361/JunDDve7_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1462547106158325761/1637534534",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Sun Apr 24 19:33:27 +0000 2022",
#                 "id": 1518312181162459137,
#                 "id_str": "1518312181162459137",
#                 "text": "This is why they're scared.\n#Bitcoin https://t.co/RlgYjbhxzs",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 28,
#                                 36
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1518310679517835267,
#                             "id_str": "1518310679517835267",
#                             "indices": [
#                                 37,
#                                 60
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                             "url": "https://t.co/RlgYjbhxzs",
#                             "display_url": "pic.twitter.com/RlgYjbhxzs",
#                             "expanded_url": "https://twitter.com/thecryptoc0up1e/status/1518312181162459137/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 675,
#                                     "resize": "fit"
#                                 },
#                                 "large": {
#                                     "w": 1920,
#                                     "h": 1080,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 383,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "id": 1518310679517835267,
#                             "id_str": "1518310679517835267",
#                             "indices": [
#                                 37,
#                                 60
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FRIfhMdXsAMZ9ob.jpg",
#                             "url": "https://t.co/RlgYjbhxzs",
#                             "display_url": "pic.twitter.com/RlgYjbhxzs",
#                             "expanded_url": "https://twitter.com/thecryptoc0up1e/status/1518312181162459137/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 675,
#                                     "resize": "fit"
#                                 },
#                                 "large": {
#                                     "w": 1920,
#                                     "h": 1080,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 383,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1395095108421292035,
#                     "id_str": "1395095108421292035",
#                     "name": "The Crypto Couple (CARLA)",
#                     "screen_name": "thecryptoc0up1e",
#                     "location": "\ud83c\uddfa\ud83c\uddf8\ud83c\uddf7\ud83c\uddf4",
#                     "description": "Bitcoin & Crypto Comedy + Satire \u2728 BTC education @theBTCouple \ud83c\udf4a | My better half @WalkerAmerica \ud83e\udde1",
#                     "url": "https://t.co/oYdnUqMnt4",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/oYdnUqMnt4",
#                                     "expanded_url": "http://thecryptocouple.bio.link",
#                                     "display_url": "thecryptocouple.bio.link",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 24502,
#                     "friends_count": 1109,
#                     "listed_count": 197,
#                     "created_at": "Wed May 19 19:13:20 +0000 2021",
#                     "favourites_count": 13772,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": false,
#                     "statuses_count": 2780,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1462912513025134595/bm7n_M_6_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1462912513025134595/bm7n_M_6_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1395095108421292035/1650833485",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 246,
#                 "favorite_count": 947,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 246,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         }
#     ],
#     "search_metadata": {
#         "completed_in": 0.085,
#         "max_id": 1518369760861425664,
#         "max_id_str": "1518369760861425664",
#         "next_results": "?max_id=1518369736094015491&q=%23Bitcoin&include_entities=1",
#         "query": "%23Bitcoin",
#         "refresh_url": "?since_id=1518369760861425664&q=%23Bitcoin&include_entities=1",
#         "count": 15,
#         "since_id": 0,
#         "since_id_str": "0"
#     }
# }
